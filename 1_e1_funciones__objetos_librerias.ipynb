# %% [markdown]
# # MA6202: Laboratorio de Ciencia de Datos
#
# **Profesor: Nicolás Caro**
#
# **24/04/2020 - E1 S4**
#
#
# **Integrantes del grupo**:
# Matías Romero
#
# Iván Zúñiga
#
# Ignacio Fierro

# %% [markdown]
# ## Ejercicio 1
#
# La estructura de esta evaluación consta de 7 preguntas. Se evaluá desde la pregunta 1 a la 6, la pregunta 7 es opcional. Tenga en cuenta que un problema de programación puede (por lo general) resolverse de múltiples maneras. Sin embargo, para optar al puntaje completo en cada pregunta, siga las indicaciones de los enunciados y utilice solo herramientas vistas en el curso.
#
# En lo que sigue de la evaluación, **no** estará permitido usar librerías ni módulos diferentes a los declarados en la siguiente celda.

# %%
'''Celda de modulos obligatorios.'''

# Librerias de manejo de consultas
import requests
import json

# Stack cientifico
import numpy as np
from scipy import stats

# Librerias de manejo de tiemop
from datetime import date, datetime
from time import sleep

# Manejo de funciones
from functools import singledispatch, update_wrapper

# %% [markdown]
# El objetivo global de esta evaluación es medir conocimientos sobre el manejo de objetos, decoradores y librerías.
# De manera simultanea, se evaluará el manejo del sistema *Git*. Por tal motivo, para este ejercicio se exige:
#
# 1. Generar un repositorio de control de versiones *Git* donde se trabajará con este archivo.
# 2. Por lo menos un commit por pregunta.
# 3. Por lo menos un merge.
#
# El formato de entrega de esta evaluación es un archivo **.zip** con el repositorio correspondiente a este trabajo.

# %% [markdown]
# ### Primera Parte: Construcción de consultas
#
# Una interfaz de programación de aplicaciones, API por sus siglas en ingles, es un conjunto de rutinas, protocolos y herramientas para crear software. Básicamente, su función es especificar cómo interactúan los componentes de una aplicación.
#
# Existe una variedad de API's con las que se puede acceder a bases de datos, estas funcionan como una capa de software intermedia, que acepta peticiones de usuarios (consultas) y entrega información empaquetada en alguna estructura estándar (respuestas).
#
# Una API en particular es la de [United States Geological Survey (USGS)](https://earthquake.usgs.gov/fdsnws/event/1/). Esta API permite acceder a bases de datos contenedoras de información sobre movimientos telúricos en todo el mundo.
#
# El objetivo de esta primera parte, es conectarse a la API de _USGS_ para recolectar la información de tales eventos entre los años 1920 y 2020.
#
# Para comenzar preste atención al siguiente *decorador*.

# %%
def singledispatchmeth(func):
    ''' Decorador que extiende a functools.singledispatch.
    
    Se puede utilizar sobre un metodo dentro de la definicion de una clase 
    para posteriormente registrar comportamientos según tipo de dato, dentro 
    de la misma clase.
    
    Args: 
    
        func: function, class method
             Metodo a decorar
    
    Returns:
    
        class method
            Retorna un metodo del tipo singledispatch.
            
    '''
    
    despachador = singledispatch(func)

    def wrapper(*args, **kwargs):
        return despachador.dispatch(args[1].__class__)(*args, **kwargs)

    wrapper.register = despachador.register
    wrapper.registry = despachador.registry
    update_wrapper(wrapper, func)
    
    return wrapper

# %% [markdown]
# Como podrá ver, la función anterior permite **replicar exactamente** el comportamiento del decorador `@functools.singledispatch` **sobre métodos** dentro de la definición de una clase.
#
#
# ### Pregunta 1
#
# Se busca hacer consultas temporales a la API de USGS, por este motivo es necesario que se extienda la clase `date` de la librería `datetime`. Un objeto tipo `date` se inicializa con 3 argumentos enteros del tipo `año`, `mes`, `dia` (en ese orden).
#
# 1. Inicialice un objeto tipo `date` para la fecha *01/01/1920*. Muestre en pantalla los atributos `.year`, `.month` y `.day`.
#
# 2. Extienda la clase `date` a una clase denotada por `DateConSuma`. Esta nueva clase debe sobrecargar el operador `+`, de manera tal, que si `data_s` es un objeto tipo `DateConSuma` y `tup = (a,b,c)` es una tupla de 3 datos tipo `int`, entonces la operación `data_s + tup` retorna un objeto tipo `DateConSuma` con atributos `.year`, `.month` y `.day` validos, dados por `data_s.year + a`,  `data_s.month + b`, `data_s.day + c`. Para esto:
#     1. Decore adecuadamente el método a sobrecargar, haciendo referencia a la clase base de `DateConSuma` por medio de `super()`.
#     2. Registre el comportamiento de dicho método decorado para que opere con tuplas, levante una excepción si la tupla a operar no tiene largo 3 o si alguno de sus elementos no es del tipo `int`.
#
# **Obs**: El método resultante no es conmutativo, es decir, no espera que `tup + data_s` esté definido.

# %%
# Respuesta P1
fecha=date(1920,1,1)
print(fecha.year,fecha.month,fecha.day)

class DateConSuma(date):
    '''Clase que extiende a 'date' y sobrecarga el operador +.'''
    @singledispatchmeth
    def __add__(self,other):
        otro = super(DateConSuma,other)
        return DateConSuma(super().year+otro.year,super().month+otro.month,super().day+otro.day)
    
    @__add__.register(tuple)
    def _(self,other):
        try:
            a,b,c=other
            d=DateConSuma(super().year+a,super().month+b,super().day+c)
            return d
        except (ValueError):
            print('Error: la tupla debe tener 3 elementos.')
        except (TypeError):
            print('Error: la tupla debe tener solo enteros.')
# Out:
# 1920 1 1

# %%
# test
d1=DateConSuma(1920,1,1)
d2=DateConSuma(1920,1,2)
t1=(1920,1,2)
t2=(1920,1,2,3)
t3=(1920,1)
t4=(1920,1,2.5)
print(d1+d2)
print(d1+t1)
print(d1+t2)
print(d1+t3)
print(d1+t4)
# Out:
# 3840-02-03
# 3840-02-03
# Error: la tupla debe tener 3 elementos.
# None
# Error: la tupla debe tener 3 elementos.
# None
# Error: la tupla debe tener solo enteros.
# None

# %% [markdown]
# ### Pregunta 2
#
# Defina la clase `IteratorFechas` que retorne objetos de la clase `DateConSuma` espaciados cada $n$ años comenzando en 1920-01-01 y finalizando en 2020-01-01. Para ello:
#
# 1. Defina el atributo estático y privado `desde_fecha`, este se asocia a un objeto `DateConSuma` que representa la fecha 1920-01-01.
#
# 2.  Defina el atributo estático y privado `hasta_fecha` este se asocia a un objeto `DateConSuma` que representa la fecha 2020-01-01.
#
# 3. El constructor debe recibir el parámetro `n`, cuyo valor se debe almacenar en el atributo `espaciado`.
#
# 4. Defina el método mágico `__iter__` donde sólo se retorne el objeto instanciado.
#
# 5. Defina el método mágico `__next__`. Para esto, si `N` representa el valor del atributo `espaciado`, entonces:
#
#     1. Si `desde_fecha` + `(N,0,0)` (sobrecarga de `+`) representa una fecha anterior a la de `hasta_fecha`, entonces se debe retornar una tupla con el valor de `desde_fecha` en su primera componente y de `desde_fecha` + `(N,0,0)` en su segunda componente. De igual manera, se requiere que el método `__next__` actualice el valor del atributo `desde_fecha` reasignandole el valor `desde_fecha` + `(N,0,0)`. *Hint*: Observe que `DateConSuma` hereda de `date`, por lo tanto las comparaciones del tipo `a < b` son validas para esta nueva clase.
#
#     2.  Si lo anterior no se cumple, entonces levante una excepción del tipo  `StopIteration` con el mensaje, `'fecha final excedida'`.
#
# 6. Inicialice el objeto `iter_fechas` de la clase `IteratorFechas` con un espaciado de 5 años. Mediante un ciclo `for` itere sobre `iter_fechas` e imprima sobre las variables iteradoras, de manera tal, que se logre un output del tipo:
#
# ```
#         Desde : 1920-01-01 Hasta:  1925-01-01
#         Desde : 1925-01-01 Hasta:  1930-01-01
#             ...
#         Desde : 2015-01-01 Hasta:  2020-01-01
# ```

# %%
class IteratorFechas:
    
    __desde_fecha=DateConSuma(1920,1,1)
    __hasta_fecha=DateConSuma(2020,1,1)
    def __init__(self,n):
        self.espaciado=n
    
    def __iter__(self):
        return self
    
    def __next__(self):
        N=self.espaciado
        if self.__desde_fecha+(N,0,0)<=self.__hasta_fecha:
            copy=self.__desde_fecha
            self.__desde_fecha=self.__desde_fecha+(N,0,0)
            return (copy,copy+(N,0,0))
        else:
            raise StopIteration('fecha final excedida')

    def next(self):
        return self.__next__()

    
iter_fechas=IteratorFechas(5)
for i in iter_fechas:
    #print(i[0],i[1])
    print('Desde : '+str(i[0])," Hasta: "+str(i[1]))
# Out:
# Desde : 1920-01-01  Hasta: 1925-01-01
# Desde : 1925-01-01  Hasta: 1930-01-01
# Desde : 1930-01-01  Hasta: 1935-01-01
# Desde : 1935-01-01  Hasta: 1940-01-01
# Desde : 1940-01-01  Hasta: 1945-01-01
# Desde : 1945-01-01  Hasta: 1950-01-01
# Desde : 1950-01-01  Hasta: 1955-01-01
# Desde : 1955-01-01  Hasta: 1960-01-01
# Desde : 1960-01-01  Hasta: 1965-01-01
# Desde : 1965-01-01  Hasta: 1970-01-01
# Desde : 1970-01-01  Hasta: 1975-01-01
# Desde : 1975-01-01  Hasta: 1980-01-01
# Desde : 1980-01-01  Hasta: 1985-01-01
# Desde : 1985-01-01  Hasta: 1990-01-01
# Desde : 1990-01-01  Hasta: 1995-01-01
# Desde : 1995-01-01  Hasta: 2000-01-01
# Desde : 2000-01-01  Hasta: 2005-01-01
# Desde : 2005-01-01  Hasta: 2010-01-01
# Desde : 2010-01-01  Hasta: 2015-01-01
# Desde : 2015-01-01  Hasta: 2020-01-01

# %% [markdown]
# La API USGS utiliza el protocolo http para recibir consultas y entregar datos de respuesta. Por lo anterior, para hacer consultas a la API, se deben producir direcciones URL siguiendo un formato especifico, en este caso el formato de consulta sigue el patrón:
#
#         https://earthquake.usgs.gov/fdsnws/event/1/ `Metodo?Parametros`
#
# En el campo `Metodo`  se utiliza `query?format=geojson` lo que implica que la respuesta entregada por la API vendrá en formato `.json`, es decir _JavaScript Object Notation_. Para efectos prácticos, este es un formato que permite almacenar información mediante una escritura análoga a los `dict` de Python. Su manejo se hace con la librería `json`.
#
# En cuanto al campo `Parametros`, estos están definidos en la documentación de la [API](https://earthquake.usgs.gov/fdsnws/event/1/) y permiten definir la información a consultar. Los parámetros que serán útiles para el ejercicio son:
#
# * **Geográficos**: que servirán para definir la zona geográfica de interés mediante un rectangulo de latitudes y longitudes. Estos son: `minlatitude`, `minlongitude`, `maxlatitude` y `maxlongitude`.
#
# * **Temporales**: que servirán para definir el periodo de consulta. Se trata de: `starttime` y `endtime`.
#
# Por lo anterior, si se desea consultar por los eventos ocurridos entre el primero de enero de 1920 y el primero de enero de 1925 la consulta sería de la forma:
#
# [https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1920-01-01&endtime=1925-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742](https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1920-01-01&endtime=1925-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742)
#
# Note que los parámetros geográficos utilizados son:
#
# ```python
# 'minlatitude': -56.72500008,
# 'minlongitude': -80,
# 'maxlatitude': -17.49839982,
# 'maxlongitude': -66.07534742,
# ```

# %% [markdown]
# ### Pregunta 3
#
# Dado que la API entrega un máximo de 20.000 respuestas por consulta y que Chile es un país con mucha actividad sísmica, es necesario realizar múltiples consultas para capturar **todos** los movimientos telúricos en cuestión.
#
# Para efectos de este ejercicio, las consultas a la API se mantendrán en una zona geográfica fija, es decir, los parámetros geográficos no varían. Se busca entonces, obtener información variando unicamente las parámetros temporales.

# %% [markdown]
# 1. Para la clase `ConstructorConsultasUSGS` defina el método `construye_consulta` que usa los atributos privados `fixed_loc` y `base_url`. Además, tal método debe recibir los argumentos `desde_fecha` y `hasta_fecha` para retornar una consulta en string con el formato admitido por la API.
#
# **Ejemplo**
#
# Se espera que el método:
#
# ```python
# date_1 = DateConSuma(1920, 1, 1)
# date_2 = DateConSuma(1925, 1, 1)
#
# ConstructorConsultasUSGS.construye_consulta(date_1, date_2)
# ```
#
# Retorne el string
#
# ```
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1920-01-01&endtime=1925-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742'
# ```

# %%
class ConstructorConsultasUSGS:
    '''Clase constructora de consultas a la API USGS.'''

    # Atributos fijos de consulta
    __fixed_loc = {
        'minlatitude': -56.72500008,
        'minlongitude': -80,
        'maxlatitude': -17.49839982,
        'maxlongitude': -66.07534742,
    }
    
    __base_url = "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson"

    
    def construye_consulta(self, desde_fecha, hasta_fecha):
        
        # Completar el codigo
        
        return

# %% [markdown]
# 2. Cree la clase `GeneradorConsulta` que herede de las clases `ConstructorConsultasUSGS` e `IteratorFechas`. Esta nueva clase es un *iterator* que en cada paso entrega una consulta a la API. Para ello haga _overridding_ (o anulación) de los metodos:
#
#     1. `__init__`: haga uso de la función `super` en dos ocasiones. *Hint*: Recuerde el MRO *como cadena* y su interacción con `super`, incialice clase base.
#     2. `__next__`: haga uso de la función `super` en dos ocasiones. *Hint*: Debe retornar una url construida con una *tupla* de fechas.
#
# **Ejemplo**
#
# Las primera y última iteración deben retornar:
#
# ```
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1920-01-01&endtime=1925-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742'
#    ...
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2015-01-01&endtime=2020-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742'
# ```

# %%
# P3 parte 1
class ConstructorConsultasUSGS:
    '''Clase constructora de consultas a la API USGS.'''

    # Atributos fijos de consulta
    __fixed_loc = {
        'minlatitude': -56.72500008,
        'minlongitude': -80,
        'maxlatitude': -17.49839982,
        'maxlongitude': -66.07534742,
    }
    
    __base_url = "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson"

    
    def construye_consulta(self, desde_fecha, hasta_fecha):
        string_desde_fecha='&starttime='+str(desde_fecha)
        string_hasta_fecha='&endtime='+str(hasta_fecha)
        string_fixed_loc='&minlatitude='+str(self.__fixed_loc['minlatitude'])+'&minlongitude='+str(self.__fixed_loc['minlongitude'])+'&maxlatitude='+str(self.__fixed_loc['maxlatitude'])+'&maxlongitude='+str(self.__fixed_loc['maxlongitude'])
        url=self.__base_url+string_desde_fecha+string_hasta_fecha+string_fixed_loc        
        return url
    
date_1 = DateConSuma(1920, 1, 1)
date_2 = DateConSuma(1925, 1, 1)
co=ConstructorConsultasUSGS()
print(co.construye_consulta(date_1,date_2))
# Out:
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1920-01-01&endtime=1925-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742

# %%
str(date_1)
# Out:
# '1920-01-01'

# %% [markdown]
# 2. Cree la clase `GeneradorConsulta` que herede de las clases `ConstructorConsultasUSGS` e `IteratorFechas`. Esta nueva clase es un *iterator* que en cada paso entrega una consulta a la API. Para ello haga _overridding_ (o anulación) de los metodos:
#
#     1. `__init__`: haga uso de la función `super` en dos ocasiones. *Hint*: Recuerde el MRO *como cadena* y su interacción con `super`, incialice clase base.
#     2. `__next__`: haga uso de la función `super` en dos ocasiones. *Hint*: Debe retornar una url construida con una *tupla* de fechas.
#
# **Ejemplo**
#
# Las primera y última iteración deben retornar:
#
# ```
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1920-01-01&endtime=1925-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742'
#    ...
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2015-01-01&endtime=2020-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742'
# ```

# %%
('https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2010-01-01&endttime=2015-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742'==
 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2015-01-01&endtime=2020-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742')
# Out:
# False

# %%
# P3 parte 2
class GeneradorConsulta(ConstructorConsultasUSGS,IteratorFechas):
    def __init__(self,n):
        constructor2=super().__init__
        constructor1=super().__init__(n)

    def __next__(self):
        date1,date2=super().__next__()
        url=super().construye_consulta(date1,date2)
        return url

generador=GeneradorConsulta(5)
for url in generador:
    print(url)
# Out:
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1920-01-01&endtime=1925-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1925-01-01&endtime=1930-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1930-01-01&endtime=1935-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1935-01-01&endtime=1940-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1940-01-01&endtime=1945-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1945-01-01&endtime=1950-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1950-01-01&endtime=1955-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1955-01-01&endtime=1960-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1960-01-01&endtime=1965-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1965-01-01&endtime=1970-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1970-01-01&endtime=1975-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1975-01-01&endtime=1980-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1980-01-01&endtime=1985-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1985-01-01&endtime=1990-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1990-01-01&endtime=1995-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1995-01-01&endtime=2000-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2000-01-01&endtime=2005-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2005-01-01&endtime=2010-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2010-01-01&endtime=2015-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2015-01-01&endtime=2020-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742

# %% [markdown]
# ## Segunda Parte: Recolección
#
# Construida la clase que genera las diferentes consultas, se procede a la recolección y analisis. Los datos seran almacendos en un diccionario con la siguiente estructura:
#
# ```python
# {
#     'id': [id_1, id_2, ..., id_n],
#     'lugar': [lugar_1, lugar_2, ..., lugar_n],
#     'timestamp': [timestamp_1, timestamp_2, ..., timestamp_n],
#     'magnitud': [magnitud_1, magnitud_2, ..., magnitud_n],
#     'longitud': [longitud_1, longitud_2, ..., longitud_n ],
#     'latitud': [latitud_1, latitud_2, ..., latitud_n]
# }
# ```

# %% [markdown]
# ### Pregunta 4
#
# Observe que la estructura anterior corresponde a un diccionario de listas. Se busca facilitar el almacenamiento de la información recolectada mediante una concatenación especial de diccionarios. Con tal fin, extienda la clase `dict`, definiendo la clase `DictDeListas`. Para esta nueva clase, defina el método `extiende_listas`, este método:
#
# 1. Recibe como argumento otro objeto del tipo `DictDeListas` y levanta una excepción del tipo `ValueError` con el mensaje  `'El argumento debe ser de la clase DictDeListas'` en caso contrario.
# 2. Para cada llave del objeto instanciado, concatena las listas asociadas a esa llave en cada uno de los dos objetos involucrados (el instanciado y el recibido como argumento). Haga uso del método `items` e itere sobre el segundo objeto `DictDeListas`.
#
# **Ejemplo**
#
# El código
#
# ```python
# # Se generan objetos DictDeListas con llaves en comun
# dict_ls_1 = DictDeListas({'llave': [1, 2,3]})
# dict_ls_2 = DictDeListas({'llave': [4, 5, 200]})
#
# # Se utiliza el metodo y se muestra su representacion __repr__
# dict_ls_1.extiende_listas(dict_ls_2)
# dict_ls_1
# ```
#
# Genera el output:
#
# ```
# {'llave': [1, 2, 3, 4, 5, 200]}
# ```

# %%
class DictDeListas(dict):
    def extiende_listas(self,other):
        if type(other)!=DictDeListas:
            raise ValueError('El argumento debe ser de la clase DictDeListas')
        else:
            for key, value in self.items():
                self[key]=self[key]+other[key]

dict_ls_1 = DictDeListas({'llave': [1, 2,3]})
dict_ls_2 = DictDeListas({'llave': [4, 5, 200]})
dict_ls_1.extiende_listas(dict_ls_2)
dict_ls_1
# Out:
# {'llave': [1, 2, 3, 4, 5, 200]}

# %% [markdown]
# Cuando se tiene una URL, basta introducirla al navegador para obtener su información asociada. En Python esto se puede realizar con la librería `requests`. En particular, el método `get` de tal librería, permite efectuar consultas en la API USGS, en efecto, si se analiza la respuesta de:

# %%
resp = requests.get(
    'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1920-01-01&endtime=1925-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742'
)

# %% [markdown]
# Notamos que dicho objeto posee las siguientes caracteristicas:
#
# 1. `__enter__` y `__exit__`.
# 2. `json`, el cual retorna el contenido codificado de la respuesta.
# 3. Un atributo `.ok` que retorna `True` si la consulta se responde con exito.
#
# Se puede observar el contenido `json` de la respuesta obtenida por medio de:

# %%
display(resp.json())
resp.close()
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1587771045000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1920-01-01&endtime=1925-01-01&minlatitude=-56.72500008&minlongitude=-80&maxlatitude=-17.49839982&maxlongitude=-66.07534742',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.8.1',
#   'count': 11},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 6.7,
#     'place': 'Atacama, Chile',
#     'time': -1449266702000,
#     'updated': 1585298188991,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/iscgem910820',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=iscgem910820&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.892,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 691,
#     'net': 'iscgem',
#     'code': '910820',
#     'ids': ',iscgem910820,',
#     'sources': ',iscgem,',
#     'types': ',origin,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': None,
#     'gap': None,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 6.7 - Atacama, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-70.755, -28.222, 45]},
#    'id': 'iscgem910820'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.2,
#     'place': 'Araucania, Chile',
#     'time': -1456469077000,
#     'updated': 1585299176553,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/iscgem911723',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=iscgem911723&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.661,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 591,
#     'net': 'iscgem',
#     'code': '911723',
#     'ids': ',iscgem911723,',
#     'sources': ',iscgem,',
#     'types': ',origin,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': None,
#     'gap': None,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 6.2 - Araucania, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-73.182, -38.708, 35]},
#    'id': 'iscgem911723'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.5,
#     'place': 'Atacama, Chile',
#     'time': -1472520790000,
#     'updated': 1585304000949,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/iscgemsup911356',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=iscgemsup911356&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 7.626,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 650,
#     'net': 'iscgemsup',
#     'code': '911356',
#     'ids': ',iscgem911356,iscgemsup911356,',
#     'sources': ',is,iscgemsup,',
#     'types': ',origin,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': None,
#     'gap': None,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 6.5 - Atacama, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.332, -28.928, 35]},
#    'id': 'iscgemsup911356'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.7,
#     'place': 'offshore Coquimbo, Chile',
#     'time': -1487077027000,
#     'updated': 1585299694038,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/iscgem912083',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=iscgem912083&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.217,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 691,
#     'net': 'iscgem',
#     'code': '912083',
#     'ids': ',iscgem912083,',
#     'sources': ',iscgem,',
#     'types': ',origin,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': None,
#     'gap': None,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 6.7 - offshore Coquimbo, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-72.489, -30.333, 15]},
#    'id': 'iscgem912083'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.6,
#     'place': 'Atacama, Chile',
#     'time': -1487569829000,
#     'updated': 1585299672464,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/iscgem912063',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=iscgem912063&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 7.086,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 670,
#     'net': 'iscgem',
#     'code': '912063',
#     'ids': ',iscgem912063,',
#     'sources': ',iscgem,',
#     'types': ',origin,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': None,
#     'gap': None,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 6.6 - Atacama, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-70.58, -28.389, 35]},
#    'id': 'iscgem912063'},
#   {'type': 'Feature',
#    'properties': {'mag': 8.5,
#     'place': 'Atacama, Chile',
#     'time': -1487618829000,
#     'updated': 1585305365782,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/official19221111043251_30',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=official19221111043251_30&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 8.032,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 1112,
#     'net': 'official',
#     'code': '19221111043251_30',
#     'ids': ',iscgem912062,official19221111043251_30,',
#     'sources': ',iscgem,official,',
#     'types': ',general-header,impact-text,origin,shakemap,trump-origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': None,
#     'gap': None,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 8.5 - Atacama, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-69.852, -28.293, 70]},
#    'id': 'official19221111043251_30'},
#   {'type': 'Feature',
#    'properties': {'mag': 7,
#     'place': 'offshore Atacama, Chile',
#     'time': -1487897983000,
#     'updated': 1585299651703,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/iscgem912057',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=iscgem912057&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.876,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 754,
#     'net': 'iscgem',
#     'code': '912057',
#     'ids': ',iscgem912057,',
#     'sources': ',iscgem,',
#     'types': ',origin,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': None,
#     'gap': None,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 7.0 - offshore Atacama, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.96, -28.365, 25]},
#    'id': 'iscgem912057'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.8,
#     'place': 'near the coast of southern Peru',
#     'time': -1514281735000,
#     'updated': 1585299241837,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/iscgem911793',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=iscgem911793&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.022,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 711,
#     'net': 'iscgem',
#     'code': '911793',
#     'ids': ',iscgem911793,',
#     'sources': ',iscgem,',
#     'types': ',origin,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': None,
#     'gap': None,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 6.8 - near the coast of southern Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-72.743, -17.734, 15]},
#    'id': 'iscgem911793'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.3,
#     'place': 'Neuquen, Argentina',
#     'time': -1548185633000,
#     'updated': 1585300289292,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/iscgem912683',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=iscgem912683&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.813,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 820,
#     'net': 'iscgem',
#     'code': '912683',
#     'ids': ',iscgem912683,',
#     'sources': ',iscgem,',
#     'types': ',origin,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': None,
#     'gap': None,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 7.3 - Neuquen, Argentina'},
#    'geometry': {'type': 'Point', 'coordinates': [-70.256, -37.723, 15]},
#    'id': 'iscgem912683'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.9,
#     'place': 'Araucania, Chile',
#     'time': -1557819859000,
#     'updated': 1585244731188,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/iscgem16958437',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=iscgem16958437&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 7.89,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 732,
#     'net': 'iscgem',
#     'code': '16958437',
#     'ids': ',iscgem16958437,',
#     'sources': ',iscgem,',
#     'types': ',origin,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': None,
#     'gap': None,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 6.9 - Araucania, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-73.017, -38.063, 15]},
#    'id': 'iscgem16958437'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.9,
#     'place': 'Catamarca, Argentina',
#     'time': -1559275359000,
#     'updated': 1585300222198,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/iscgem912573',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=iscgem912573&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 6.463,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 732,
#     'net': 'iscgem',
#     'code': '912573',
#     'ids': ',iscgem912573,',
#     'sources': ',iscgem,',
#     'types': ',origin,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': None,
#     'gap': None,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 6.9 - Catamarca, Argentina'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.848, -27.398, 15]},
#    'id': 'iscgem912573'}],
#  'bbox': [-73.182, -38.708, 15, -67.848, -17.734, 70]}

# %% [markdown]
# Aqui, se aprecia que la respuesta es un `dict` que contiene diferentes pares de (llaves, valor) de tipo (`str`, `obj`) donde`obj` puede ser `dict`, `list`, `str`, `int`, `float`, `NoneType`, etc...

# %% [markdown]
# Para esta pregunta, nos centraremos en la llave `'features'`, que contiene una lista con elementos de tipo `dict` con la información recolectada.
#
# ### Pregunta 5
#
# Las siguientes funciones lambda retornan los atributos de interés, observe que está en presencia de un diccionario de funciones

# %%
funciones_dict = {
    'id': lambda x: x['id'],
    'lugar': lambda x: x['properties']['place'],
    'timestamp': lambda x: datetime.fromtimestamp(
        x['properties']['time'] // 1000),
    'magnitud': lambda x: x['properties']['mag'],
    'longitud': lambda x: x['geometry']['coordinates'][0],
    'latitud': lambda x: x['geometry']['coordinates'][1]
}

# %% [markdown]
# Así para obtener los atributos de interés del primer elemento asociado a `'features'` (primera observación) se puede ejecutar:

# %%
{k: func(resp.json()['features'][0]) for k, func in funciones_dict.items()}
# Out:
# {'id': 'iscgem910820',
#  'lugar': 'Atacama, Chile',
#  'timestamp': datetime.datetime(1924, 1, 28, 21, 12, 12),
#  'magnitud': 6.7,
#  'longitud': -70.755,
#  'latitud': -28.222}

# %% [markdown]
# Recolecte los datos de la API haciendo uso de `funciones_dict`. En el siguiente procedimiento complete las 3 lineas indicadas con:
# ```python
#     _ _ _ _ # Completar {n}
#
# ```
# Para esto:
# 1. En **Completar 1** haga uso de la función `map` y una conversión de tipo de dato a `list`.
# 2. En **Completar 2** y **Completar 3**, opere sobre `observaciones_dict` y obtenga un objeto `DictDeListas` con la concatenación de todos los atributos de interés, para cada las consulta realizada a la API. *Hint* : recuerde la razón por la que definimos `DictDeListas`.
#
# **Obs**: La cantidad de observaciones recolectadas debería ser mayor a  63.500. Puede acceder a este dato por medio de `len(observaciones_dict['id'])`.

# %%
# Respeusta P5

# Inicializar el contenedor de los datos recolectados
observaciones_dict = DictDeListas()

# Generar las url de las consultas a la API
for consulta_str in GeneradorConsulta(5):
    # Abre un context manager
    with requests.get(consulta_str) as respuesta:
        
        # Verifica con el atributo .ok si se recibe la informacion
        assert respuesta.ok, 'Respuesta erronea'
    
        # Almacena las features de interes
        respuesta_dict = respuesta.json()
        respuesta_features_lista = respuesta_dict['features']


        # Reporta numero de resultados obtenidos en la iteracion
        print('Se obtuvieron', len(respuesta_dict["features"]), 'observaciones \n')
        # Inicializa un contenedor de resultados
        iter_dict = DictDeListas()

        for k, func in funciones_dict.items():
            iter_dict[k] = list(map(func,respuesta_features_lista))
        
        # Verifica si observaciones_dict esta vacio
        if observaciones_dict:
            observaciones_dict.extiende_listas(iter_dict)
        else:
            observaciones_dict=iter_dict
        sleep(5)
# Out:
# Se obtuvieron 11 observaciones
#
# Se obtuvieron 10 observaciones
#
# Se obtuvieron 6 observaciones
#
# Se obtuvieron 5 observaciones
#
# Se obtuvieron 10 observaciones
#
# Se obtuvieron 5 observaciones
#
# Se obtuvieron 18 observaciones
#
# Se obtuvieron 24 observaciones
#
# Se obtuvieron 75 observaciones
#
# Se obtuvieron 49 observaciones
#
# Se obtuvieron 610 observaciones
#
# Se obtuvieron 1605 observaciones
#
# Se obtuvieron 3604 observaciones
#
# Se obtuvieron 5553 observaciones
#
# Se obtuvieron 7810 observaciones
#
# Se obtuvieron 10502 observaciones
#
# Se obtuvieron 13248 observaciones
#
# Se obtuvieron 9509 observaciones
#
# Se obtuvieron 5553 observaciones
#
# Se obtuvieron 5356 observaciones

# %% [markdown]
# Finalmente es posible proceder al análisis de los datos. Para ello se hará uso de  las librerías `numpy` y `scipy`. El primer paso será transformar las listas en numpy array usando los siguientes tipos de datos:

# %%
dtype_dict = {
    'id': np.dtype('<U64'),
    'lugar': np.dtype('<U64'),
    'timestamp': np.dtype('<M8[ns]'),
    'magnitud': np.dtype(float),
    'longitud': np.dtype(float),
    'latitud': np.dtype(float)
}
dtype_dict
# Out:
# {'id': dtype('<U64'),
#  'lugar': dtype('<U64'),
#  'timestamp': dtype('<M8[ns]'),
#  'magnitud': dtype('float64'),
#  'longitud': dtype('float64'),
#  'latitud': dtype('float64')}

# %%
observaciones_dict['timestamp']
# Out:
# [datetime.datetime(1924, 1, 28, 21, 12, 12),
#  datetime.datetime(1923, 11, 6, 12, 32, 37),
#  datetime.datetime(1923, 5, 4, 17, 44, 4),
#  datetime.datetime(1922, 11, 17, 6, 20, 7),
#  datetime.datetime(1922, 11, 11, 13, 26, 45),
#  datetime.datetime(1922, 11, 10, 23, 50, 5),
#  datetime.datetime(1922, 11, 7, 18, 17, 31),
#  datetime.datetime(1922, 1, 6, 9, 28, 19),
#  datetime.datetime(1920, 12, 9, 23, 43, 21),
#  datetime.datetime(1920, 8, 20, 11, 32, 55),
#  datetime.datetime(1920, 8, 3, 15, 14, 35),
#  datetime.datetime(1929, 10, 19, 6, 12, 54),
#  datetime.datetime(1929, 5, 30, 4, 43, 26),
#  datetime.datetime(1928, 12, 2, 0, 20, 25),
#  datetime.datetime(1928, 12, 1, 0, 6, 17),
#  datetime.datetime(1928, 11, 20, 16, 35, 12),
#  datetime.datetime(1928, 1, 12, 9, 6, 43),
#  datetime.datetime(1927, 11, 21, 19, 12, 32),
#  datetime.datetime(1927, 11, 14, 3, 19, 30),
#  datetime.datetime(1927, 2, 28, 9, 25, 11),
#  datetime.datetime(1925, 5, 15, 7, 14, 19),
#  datetime.datetime(1934, 12, 4, 13, 24, 33),
#  datetime.datetime(1934, 3, 1, 17, 45, 15),
#  datetime.datetime(1933, 2, 23, 4, 9, 19),
#  datetime.datetime(1932, 11, 29, 7, 11),
#  datetime.datetime(1931, 3, 18, 4, 2, 25),
#  datetime.datetime(1930, 7, 12, 20, 12, 9),
#  datetime.datetime(1939, 4, 18, 2, 22, 44),
#  datetime.datetime(1939, 1, 24, 23, 32, 15),
#  datetime.datetime(1937, 3, 14, 7, 55, 47),
#  datetime.datetime(1936, 7, 26, 3, 36, 58),
#  datetime.datetime(1936, 7, 13, 7, 12, 18),
#  datetime.datetime(1944, 12, 22, 18, 31, 45),
#  datetime.datetime(1944, 1, 15, 19, 49, 32),
#  datetime.datetime(1943, 11, 29, 15, 37, 3),
#  datetime.datetime(1943, 5, 22, 5, 2, 1),
#  datetime.datetime(1943, 4, 6, 12, 7, 17),
#  datetime.datetime(1942, 7, 8, 1, 55, 44),
#  datetime.datetime(1940, 10, 11, 14, 41, 19),
#  datetime.datetime(1940, 10, 6, 11, 38, 25),
#  datetime.datetime(1940, 10, 4, 3, 55, 2),
#  datetime.datetime(1940, 10, 1, 6, 42, 50),
#  datetime.datetime(1949, 12, 17, 11, 7, 58),
#  datetime.datetime(1949, 12, 17, 2, 53, 32),
#  datetime.datetime(1949, 4, 19, 23, 29, 10),
#  datetime.datetime(1946, 8, 2, 16, 18, 52),
#  datetime.datetime(1946, 7, 26, 3, 44, 48),
#  datetime.datetime(1954, 7, 26, 16, 15, 52),
#  datetime.datetime(1954, 7, 23, 0, 33, 34),
#  datetime.datetime(1953, 12, 20, 5, 19, 49),
#  datetime.datetime(1953, 9, 4, 10, 7, 17),
#  datetime.datetime(1953, 7, 31, 18, 57, 35),
#  datetime.datetime(1953, 5, 6, 13, 16, 48),
#  datetime.datetime(1952, 12, 9, 1, 47, 36),
#  datetime.datetime(1952, 8, 18, 9, 5, 2),
#  datetime.datetime(1952, 7, 5, 19, 6, 19),
#  datetime.datetime(1952, 6, 10, 20, 31, 43),
#  datetime.datetime(1952, 5, 23, 21, 59, 11),
#  datetime.datetime(1951, 5, 15, 1, 18, 39),
#  datetime.datetime(1951, 5, 10, 17, 32, 57),
#  datetime.datetime(1951, 4, 1, 16, 45, 29),
#  datetime.datetime(1951, 1, 3, 13, 27, 18),
#  datetime.datetime(1950, 12, 9, 17, 38, 51),
#  datetime.datetime(1950, 1, 29, 20, 56, 35),
#  datetime.datetime(1950, 1, 3, 7, 6, 28),
#  datetime.datetime(1959, 11, 28, 8, 35),
#  datetime.datetime(1959, 6, 13, 20, 12, 6),
#  datetime.datetime(1959, 5, 21, 7, 34, 28),
#  datetime.datetime(1959, 4, 8, 7, 44, 29),
#  datetime.datetime(1959, 1, 30, 12, 15, 51),
#  datetime.datetime(1959, 1, 28, 6, 4, 13),
#  datetime.datetime(1958, 9, 4, 17, 51, 16),
#  datetime.datetime(1958, 8, 28, 5, 36, 8),
#  datetime.datetime(1958, 7, 11, 15, 10, 30),
#  datetime.datetime(1957, 12, 20, 7, 18, 47),
#  datetime.datetime(1957, 11, 29, 18, 19, 50),
#  datetime.datetime(1957, 7, 29, 13, 15, 19),
#  datetime.datetime(1957, 7, 23, 21, 57, 38),
#  datetime.datetime(1956, 12, 17, 22, 31, 11),
#  datetime.datetime(1956, 6, 11, 5, 56, 21),
#  datetime.datetime(1956, 6, 9, 6, 8, 29),
#  datetime.datetime(1956, 1, 18, 4, 7, 23),
#  datetime.datetime(1956, 1, 8, 16, 54, 23),
#  datetime.datetime(1955, 12, 6, 0, 31, 5),
#  datetime.datetime(1955, 11, 17, 2, 53, 33),
#  datetime.datetime(1955, 7, 27, 21, 59, 34),
#  datetime.datetime(1955, 4, 20, 1, 48, 35),
#  datetime.datetime(1955, 4, 19, 22, 12, 34),
#  datetime.datetime(1955, 4, 19, 16, 24, 10),
#  datetime.datetime(1964, 11, 18, 1, 1, 45),
#  datetime.datetime(1964, 8, 18, 0, 45, 1),
#  datetime.datetime(1964, 8, 5, 18, 23, 12),
#  datetime.datetime(1964, 7, 25, 15, 31, 10),
#  datetime.datetime(1963, 12, 3, 19, 3, 46),
#  datetime.datetime(1963, 8, 26, 23, 23, 33),
#  datetime.datetime(1963, 5, 18, 21, 3, 3),
#  datetime.datetime(1963, 5, 18, 1, 33, 26),
#  datetime.datetime(1963, 3, 10, 6, 51, 48),
#  datetime.datetime(1963, 3, 7, 8, 16, 27),
#  datetime.datetime(1963, 2, 5, 21, 21, 29),
#  datetime.datetime(1963, 2, 5, 16, 39, 20),
#  datetime.datetime(1963, 1, 11, 8, 12, 16),
#  datetime.datetime(1962, 12, 29, 6, 41, 6),
#  datetime.datetime(1962, 11, 11, 18, 14, 18),
#  datetime.datetime(1962, 11, 4, 18, 53, 34),
#  datetime.datetime(1962, 8, 3, 4, 56, 20),
#  datetime.datetime(1962, 7, 17, 1, 32, 10),
#  datetime.datetime(1962, 6, 15, 2, 30, 37),
#  datetime.datetime(1962, 3, 26, 12, 32, 45),
#  datetime.datetime(1962, 2, 27, 8, 40, 46),
#  datetime.datetime(1962, 2, 14, 2, 36, 5),
#  datetime.datetime(1961, 12, 24, 19, 43, 20),
#  datetime.datetime(1961, 12, 9, 7, 18, 11),
#  datetime.datetime(1961, 10, 18, 12, 51, 57),
#  datetime.datetime(1961, 9, 13, 17, 19, 18),
#  datetime.datetime(1961, 6, 16, 3, 8, 20),
#  datetime.datetime(1961, 5, 11, 4, 38, 29),
#  datetime.datetime(1961, 5, 8, 15, 23, 39),
#  datetime.datetime(1961, 4, 8, 13, 59, 47),
#  datetime.datetime(1960, 12, 31, 14, 8, 9),
#  datetime.datetime(1960, 12, 29, 6, 36, 45),
#  datetime.datetime(1960, 12, 6, 4, 56, 16),
#  datetime.datetime(1960, 12, 2, 5, 10, 48),
#  datetime.datetime(1960, 11, 29, 5, 31, 58),
#  datetime.datetime(1960, 11, 22, 8, 28, 54),
#  datetime.datetime(1960, 11, 9, 16, 6, 20),
#  datetime.datetime(1960, 11, 1, 4, 45, 59),
#  datetime.datetime(1960, 10, 30, 8, 14, 37),
#  datetime.datetime(1960, 10, 14, 13, 48, 32),
#  datetime.datetime(1960, 8, 13, 10, 14, 56),
#  datetime.datetime(1960, 7, 31, 10, 54, 58),
#  datetime.datetime(1960, 7, 27, 6, 4, 57),
#  datetime.datetime(1960, 7, 5, 1, 45, 30),
#  datetime.datetime(1960, 7, 2, 4, 58, 8),
#  datetime.datetime(1960, 6, 28, 21, 57, 19),
#  datetime.datetime(1960, 6, 20, 8, 59, 46),
#  datetime.datetime(1960, 6, 19, 22, 1, 14),
#  datetime.datetime(1960, 6, 13, 1, 47, 9),
#  datetime.datetime(1960, 6, 6, 1, 55, 48),
#  datetime.datetime(1960, 6, 2, 1, 58, 6),
#  datetime.datetime(1960, 6, 1, 1, 3, 2),
#  datetime.datetime(1960, 5, 30, 22, 40, 4),
#  datetime.datetime(1960, 5, 29, 17, 23, 59),
#  datetime.datetime(1960, 5, 29, 4, 34, 25),
#  datetime.datetime(1960, 5, 29, 3, 39, 33),
#  datetime.datetime(1960, 5, 28, 7, 5, 47),
#  datetime.datetime(1960, 5, 27, 19, 6, 57),
#  datetime.datetime(1960, 5, 25, 4, 34, 42),
#  datetime.datetime(1960, 5, 24, 16, 32, 46),
#  datetime.datetime(1960, 5, 23, 6, 38, 4),
#  datetime.datetime(1960, 5, 23, 5, 52, 22),
#  datetime.datetime(1960, 5, 23, 3, 9, 21),
#  datetime.datetime(1960, 5, 23, 1, 13, 39),
#  datetime.datetime(1960, 5, 22, 22, 56, 20),
#  datetime.datetime(1960, 5, 22, 22, 46, 35),
#  datetime.datetime(1960, 5, 22, 20, 25, 48),
#  datetime.datetime(1960, 5, 22, 15, 11, 20),
#  datetime.datetime(1960, 5, 22, 14, 56, 2),
#  datetime.datetime(1960, 5, 22, 6, 32, 47),
#  datetime.datetime(1960, 5, 22, 6, 30, 44),
#  datetime.datetime(1960, 5, 22, 4, 10, 59),
#  datetime.datetime(1960, 5, 22, 2, 1, 39),
#  datetime.datetime(1960, 5, 21, 9, 0, 4),
#  datetime.datetime(1960, 5, 21, 6, 2, 57),
#  datetime.datetime(1969, 11, 13, 3, 51, 30),
#  datetime.datetime(1969, 10, 22, 6, 21, 53),
#  datetime.datetime(1969, 9, 1, 23, 47, 10),
#  datetime.datetime(1969, 4, 26, 2, 2, 52),
#  datetime.datetime(1969, 4, 26, 1, 58, 53),
#  datetime.datetime(1968, 10, 8, 10, 53, 38),
#  datetime.datetime(1968, 9, 22, 17, 52, 59),
#  datetime.datetime(1968, 9, 11, 14, 26, 36),
#  datetime.datetime(1968, 6, 19, 15, 58, 3),
#  datetime.datetime(1968, 3, 21, 21, 55, 44),
#  datetime.datetime(1968, 2, 6, 7, 19, 27),
#  datetime.datetime(1968, 1, 19, 10, 39, 39),
#  datetime.datetime(1968, 1, 13, 12, 7, 4),
#  datetime.datetime(1968, 1, 6, 19, 27, 23),
#  datetime.datetime(1967, 12, 27, 5, 17, 54),
#  datetime.datetime(1967, 12, 25, 6, 41, 32),
#  datetime.datetime(1967, 12, 20, 22, 25, 26),
#  datetime.datetime(1967, 11, 27, 1, 13, 14),
#  datetime.datetime(1967, 11, 15, 17, 31, 56),
#  datetime.datetime(1967, 9, 26, 12, 11, 24),
#  datetime.datetime(1967, 9, 26, 7, 11, 25),
#  datetime.datetime(1967, 8, 20, 11, 3, 36),
#  datetime.datetime(1967, 6, 21, 16, 9, 32),
#  datetime.datetime(1967, 6, 10, 1, 26, 44),
#  datetime.datetime(1967, 5, 11, 11, 5, 23),
#  datetime.datetime(1967, 3, 13, 12, 6, 53),
#  datetime.datetime(1966, 12, 28, 4, 18, 7),
#  datetime.datetime(1966, 11, 25, 22, 18, 19),
#  datetime.datetime(1966, 11, 12, 7, 50, 33),
#  datetime.datetime(1966, 11, 9, 23, 2, 34),
#  datetime.datetime(1966, 7, 27, 0, 49, 1),
#  datetime.datetime(1966, 5, 17, 12, 58, 16),
#  datetime.datetime(1966, 4, 21, 23, 6, 35),
#  datetime.datetime(1966, 4, 12, 23, 35, 18),
#  datetime.datetime(1966, 4, 12, 19, 37, 42),
#  datetime.datetime(1966, 4, 10, 12, 36, 16),
#  datetime.datetime(1966, 3, 8, 16, 46, 12),
#  datetime.datetime(1966, 2, 28, 17, 38, 54),
#  datetime.datetime(1965, 11, 27, 23, 56, 46),
#  datetime.datetime(1965, 11, 13, 13, 59, 43),
#  datetime.datetime(1965, 10, 3, 12, 14, 57),
#  datetime.datetime(1965, 8, 20, 5, 42, 50),
#  datetime.datetime(1965, 7, 12, 9, 57, 15),
#  datetime.datetime(1965, 6, 12, 14, 50, 12),
#  datetime.datetime(1965, 5, 3, 12, 9, 9),
#  datetime.datetime(1965, 5, 2, 21, 9, 34),
#  datetime.datetime(1965, 3, 28, 12, 33, 16),
#  datetime.datetime(1965, 3, 22, 18, 56, 27),
#  datetime.datetime(1965, 2, 23, 18, 11, 47),
#  datetime.datetime(1974, 12, 31, 7, 48, 49),
#  datetime.datetime(1974, 12, 29, 14, 20, 47),
#  datetime.datetime(1974, 12, 29, 12, 6, 21),
#  datetime.datetime(1974, 12, 25, 15, 1, 19),
#  datetime.datetime(1974, 12, 24, 13, 47, 35),
#  datetime.datetime(1974, 12, 22, 13, 44, 15),
#  datetime.datetime(1974, 12, 22, 1, 43, 35),
#  datetime.datetime(1974, 12, 21, 14, 2, 22),
#  datetime.datetime(1974, 12, 15, 15, 36, 10),
#  datetime.datetime(1974, 12, 14, 12, 39, 33),
#  datetime.datetime(1974, 12, 14, 11, 7, 18),
#  datetime.datetime(1974, 12, 13, 10, 23, 37),
#  datetime.datetime(1974, 12, 11, 13, 34, 26),
#  datetime.datetime(1974, 12, 10, 22, 9, 15),
#  datetime.datetime(1974, 12, 6, 20, 24, 56),
#  datetime.datetime(1974, 12, 6, 4, 37, 29),
#  datetime.datetime(1974, 12, 4, 7, 55, 11),
#  datetime.datetime(1974, 12, 2, 10, 48, 20),
#  datetime.datetime(1974, 12, 2, 8, 4, 2),
#  datetime.datetime(1974, 12, 2, 5, 30, 18),
#  datetime.datetime(1974, 12, 1, 2, 46, 50),
#  datetime.datetime(1974, 11, 29, 19, 27, 26),
#  datetime.datetime(1974, 11, 26, 1, 46, 47),
#  datetime.datetime(1974, 11, 26, 0, 34, 30),
#  datetime.datetime(1974, 11, 23, 20, 35, 8),
#  datetime.datetime(1974, 11, 19, 1, 0, 47),
#  datetime.datetime(1974, 11, 19, 0, 33, 7),
#  datetime.datetime(1974, 11, 16, 22, 15, 3),
#  datetime.datetime(1974, 11, 14, 21, 34, 3),
#  datetime.datetime(1974, 11, 14, 14, 57, 35),
#  datetime.datetime(1974, 11, 12, 2, 59, 51),
#  datetime.datetime(1974, 11, 7, 6, 51, 41),
#  datetime.datetime(1974, 11, 5, 6, 8, 12),
#  datetime.datetime(1974, 11, 4, 6, 55, 20),
#  datetime.datetime(1974, 11, 3, 8, 54, 29),
#  datetime.datetime(1974, 11, 2, 9, 28, 32),
#  datetime.datetime(1974, 11, 2, 3, 15, 16),
#  datetime.datetime(1974, 10, 29, 8, 10, 48),
#  datetime.datetime(1974, 10, 28, 10, 30, 51),
#  datetime.datetime(1974, 10, 26, 17, 33, 34),
#  datetime.datetime(1974, 10, 22, 6, 3, 1),
#  datetime.datetime(1974, 10, 19, 19, 2, 41),
#  datetime.datetime(1974, 10, 19, 8, 18, 49),
#  datetime.datetime(1974, 10, 18, 17, 21, 47),
#  datetime.datetime(1974, 10, 15, 1, 52, 1),
#  datetime.datetime(1974, 10, 14, 21, 24, 47),
#  datetime.datetime(1974, 10, 13, 12, 47, 43),
#  datetime.datetime(1974, 10, 12, 11, 27, 5),
#  datetime.datetime(1974, 10, 11, 15, 4, 34),
#  datetime.datetime(1974, 10, 8, 19, 38, 18),
#  datetime.datetime(1974, 10, 7, 7, 20, 18),
#  datetime.datetime(1974, 10, 7, 3, 20, 3),
#  datetime.datetime(1974, 10, 5, 19, 41, 21),
#  datetime.datetime(1974, 10, 4, 5, 14, 30),
#  datetime.datetime(1974, 10, 3, 19, 51, 21),
#  datetime.datetime(1974, 10, 1, 0, 57, 21),
#  datetime.datetime(1974, 9, 30, 16, 43, 7),
#  datetime.datetime(1974, 9, 30, 16, 39, 11),
#  datetime.datetime(1974, 9, 29, 6, 13, 4),
#  datetime.datetime(1974, 9, 29, 0, 22, 12),
#  datetime.datetime(1974, 9, 27, 21, 8, 6),
#  datetime.datetime(1974, 9, 26, 20, 5, 28),
#  datetime.datetime(1974, 9, 25, 19, 7, 15),
#  datetime.datetime(1974, 9, 25, 1, 0, 34),
#  datetime.datetime(1974, 9, 22, 21, 32, 58),
#  datetime.datetime(1974, 9, 21, 17, 0, 46),
#  datetime.datetime(1974, 9, 21, 13, 5, 15),
#  datetime.datetime(1974, 9, 20, 20, 4, 22),
#  datetime.datetime(1974, 9, 20, 6, 59, 53),
#  datetime.datetime(1974, 9, 20, 0, 48, 33),
#  datetime.datetime(1974, 9, 18, 22, 30, 40),
#  datetime.datetime(1974, 9, 18, 9, 35, 51),
#  datetime.datetime(1974, 9, 16, 23, 25, 20),
#  datetime.datetime(1974, 9, 12, 6, 3, 9),
#  datetime.datetime(1974, 9, 11, 2, 24, 39),
#  datetime.datetime(1974, 9, 10, 21, 21, 42),
#  datetime.datetime(1974, 9, 8, 4, 58, 44),
#  datetime.datetime(1974, 9, 8, 3, 1, 18),
#  datetime.datetime(1974, 9, 7, 16, 18, 45),
#  datetime.datetime(1974, 9, 7, 15, 53, 36),
#  datetime.datetime(1974, 9, 6, 10, 5, 32),
#  datetime.datetime(1974, 9, 3, 23, 40, 37),
#  datetime.datetime(1974, 9, 3, 16, 22, 18),
#  datetime.datetime(1974, 9, 2, 4, 45, 16),
#  datetime.datetime(1974, 9, 1, 17, 15, 32),
#  datetime.datetime(1974, 8, 31, 11, 12, 23),
#  datetime.datetime(1974, 8, 31, 7, 36, 49),
#  datetime.datetime(1974, 8, 30, 0, 54, 52),
#  datetime.datetime(1974, 8, 28, 16, 39, 22),
#  datetime.datetime(1974, 8, 28, 5, 53, 42),
#  datetime.datetime(1974, 8, 27, 11, 20, 49),
#  datetime.datetime(1974, 8, 27, 3, 26, 54),
#  datetime.datetime(1974, 8, 27, 2, 24, 7),
#  datetime.datetime(1974, 8, 24, 21, 30, 51),
#  datetime.datetime(1974, 8, 24, 14, 58, 22),
#  datetime.datetime(1974, 8, 24, 14, 48, 43),
#  datetime.datetime(1974, 8, 24, 7, 49, 21),
#  datetime.datetime(1974, 8, 24, 0, 16, 27),
#  datetime.datetime(1974, 8, 23, 8, 0, 35),
#  datetime.datetime(1974, 8, 21, 19, 59, 2),
#  datetime.datetime(1974, 8, 21, 1, 34, 44),
#  datetime.datetime(1974, 8, 20, 17, 37, 35),
#  datetime.datetime(1974, 8, 18, 23, 55, 58),
#  datetime.datetime(1974, 8, 18, 19, 7, 47),
#  datetime.datetime(1974, 8, 18, 15, 53, 28),
#  datetime.datetime(1974, 8, 18, 10, 48, 32),
#  datetime.datetime(1974, 8, 18, 6, 44, 12),
#  datetime.datetime(1974, 8, 17, 10, 38, 38),
#  datetime.datetime(1974, 8, 16, 3, 47, 49),
#  datetime.datetime(1974, 8, 15, 14, 27, 29),
#  datetime.datetime(1974, 8, 14, 13, 56, 47),
#  datetime.datetime(1974, 8, 14, 7, 16, 25),
#  datetime.datetime(1974, 8, 13, 0, 27, 13),
#  datetime.datetime(1974, 8, 10, 5, 49, 20),
#  datetime.datetime(1974, 8, 9, 18, 17, 19),
#  datetime.datetime(1974, 8, 4, 20, 10, 51),
#  datetime.datetime(1974, 8, 4, 17, 8, 52),
#  datetime.datetime(1974, 8, 3, 21, 25, 24),
#  datetime.datetime(1974, 7, 31, 23, 5, 14),
#  datetime.datetime(1974, 7, 31, 8, 7, 11),
#  datetime.datetime(1974, 7, 27, 6, 5, 20),
#  datetime.datetime(1974, 7, 24, 12, 58, 58),
#  datetime.datetime(1974, 7, 22, 14, 12, 15),
#  datetime.datetime(1974, 7, 20, 0, 56, 20),
#  datetime.datetime(1974, 7, 18, 22, 2, 51),
#  datetime.datetime(1974, 7, 18, 14, 29, 50),
#  datetime.datetime(1974, 7, 18, 3, 15, 40),
#  datetime.datetime(1974, 7, 17, 10, 26, 25),
#  datetime.datetime(1974, 7, 17, 5, 54, 16),
#  datetime.datetime(1974, 7, 15, 5, 30, 23),
#  datetime.datetime(1974, 7, 14, 22, 27, 32),
#  datetime.datetime(1974, 7, 10, 13, 50, 58),
#  datetime.datetime(1974, 7, 8, 20, 13, 15),
#  datetime.datetime(1974, 7, 7, 20, 44, 14),
#  datetime.datetime(1974, 6, 30, 4, 45, 45),
#  datetime.datetime(1974, 6, 30, 2, 49, 23),
#  datetime.datetime(1974, 6, 29, 8, 46, 50),
#  datetime.datetime(1974, 6, 29, 6, 58, 21),
#  datetime.datetime(1974, 6, 29, 6, 37, 36),
#  datetime.datetime(1974, 6, 27, 8, 40, 26),
#  datetime.datetime(1974, 6, 26, 14, 40, 39),
#  datetime.datetime(1974, 6, 26, 0, 23, 43),
#  datetime.datetime(1974, 6, 22, 20, 33, 18),
#  datetime.datetime(1974, 6, 22, 9, 24),
#  datetime.datetime(1974, 6, 14, 7, 56, 58),
#  datetime.datetime(1974, 6, 13, 14, 11, 40),
#  datetime.datetime(1974, 6, 10, 20, 15, 4),
#  datetime.datetime(1974, 6, 8, 10, 52, 24),
#  datetime.datetime(1974, 6, 6, 7, 27, 26),
#  datetime.datetime(1974, 6, 4, 22, 1, 11),
#  datetime.datetime(1974, 6, 2, 22, 10, 35),
#  datetime.datetime(1974, 6, 1, 10, 5, 40),
#  datetime.datetime(1974, 5, 23, 3, 1, 9),
#  datetime.datetime(1974, 5, 21, 10, 7, 43),
#  datetime.datetime(1974, 5, 17, 22, 35, 45),
#  datetime.datetime(1974, 5, 16, 9, 7),
#  datetime.datetime(1974, 5, 12, 6, 5, 55),
#  datetime.datetime(1974, 5, 4, 6, 46, 39),
#  datetime.datetime(1974, 5, 4, 2, 6, 15),
#  datetime.datetime(1974, 5, 3, 19, 20, 19),
#  datetime.datetime(1974, 4, 30, 16, 37, 40),
#  datetime.datetime(1974, 4, 26, 2, 12, 20),
#  datetime.datetime(1974, 4, 25, 19, 34, 20),
#  datetime.datetime(1974, 4, 23, 0, 23, 31),
#  datetime.datetime(1974, 4, 15, 10, 56, 9),
#  datetime.datetime(1974, 4, 11, 11, 5, 2),
#  datetime.datetime(1974, 4, 9, 6, 52, 14),
#  datetime.datetime(1974, 4, 9, 4, 7, 58),
#  datetime.datetime(1974, 4, 7, 15, 24, 8),
#  datetime.datetime(1974, 3, 29, 22, 15, 15),
#  datetime.datetime(1974, 3, 24, 12, 42, 56),
#  datetime.datetime(1974, 3, 24, 6, 8, 43),
#  datetime.datetime(1974, 3, 23, 19, 35, 18),
#  datetime.datetime(1974, 3, 23, 15, 28, 52),
#  datetime.datetime(1974, 3, 9, 3, 1, 1),
#  datetime.datetime(1974, 3, 5, 14, 15, 4),
#  datetime.datetime(1974, 3, 3, 20, 55, 46),
#  datetime.datetime(1974, 3, 1, 1, 36, 13),
#  datetime.datetime(1974, 2, 28, 7, 49, 4),
#  datetime.datetime(1974, 2, 26, 21, 11, 10),
#  datetime.datetime(1974, 2, 26, 15, 46, 15),
#  datetime.datetime(1974, 2, 25, 6, 14, 40),
#  datetime.datetime(1974, 2, 24, 18, 31, 48),
#  datetime.datetime(1974, 2, 21, 15, 17, 51),
#  datetime.datetime(1974, 2, 21, 11, 27, 5),
#  datetime.datetime(1974, 2, 21, 0, 42, 57),
#  datetime.datetime(1974, 2, 20, 0, 2, 53),
#  datetime.datetime(1974, 2, 16, 10, 13),
#  datetime.datetime(1974, 2, 15, 22, 26, 59),
#  datetime.datetime(1974, 2, 14, 3, 19, 55),
#  datetime.datetime(1974, 2, 13, 4, 30, 34),
#  datetime.datetime(1974, 2, 9, 23, 9, 11),
#  datetime.datetime(1974, 2, 9, 10, 7, 44),
#  datetime.datetime(1974, 2, 9, 7, 46),
#  datetime.datetime(1974, 2, 8, 3, 49, 46),
#  datetime.datetime(1974, 2, 8, 2, 27, 4),
#  datetime.datetime(1974, 2, 6, 15, 58),
#  datetime.datetime(1974, 2, 5, 14, 53, 37),
#  datetime.datetime(1974, 2, 4, 12, 40, 19),
#  datetime.datetime(1974, 2, 3, 5, 32, 9),
#  datetime.datetime(1974, 1, 24, 5, 21, 30),
#  datetime.datetime(1974, 1, 23, 18, 43, 51),
#  datetime.datetime(1974, 1, 21, 22, 11, 17),
#  datetime.datetime(1974, 1, 21, 9, 4, 31),
#  datetime.datetime(1974, 1, 19, 6, 52, 58),
#  datetime.datetime(1974, 1, 17, 6, 14, 11),
#  datetime.datetime(1974, 1, 14, 11, 21, 7),
#  datetime.datetime(1974, 1, 14, 10, 15, 14),
#  datetime.datetime(1974, 1, 13, 20, 35, 45),
#  datetime.datetime(1974, 1, 12, 20, 46, 44),
#  datetime.datetime(1974, 1, 12, 6, 41, 18),
#  datetime.datetime(1974, 1, 11, 2, 18, 2),
#  datetime.datetime(1974, 1, 9, 6, 4, 42),
#  datetime.datetime(1974, 1, 7, 16, 37, 40),
#  datetime.datetime(1974, 1, 7, 5, 48, 26),
#  datetime.datetime(1974, 1, 7, 3, 28, 11),
#  datetime.datetime(1974, 1, 4, 12, 9, 40),
#  datetime.datetime(1974, 1, 3, 15, 37, 43),
#  datetime.datetime(1974, 1, 3, 0, 35, 20),
#  datetime.datetime(1974, 1, 2, 10, 33, 49),
#  datetime.datetime(1974, 1, 2, 7, 42, 29),
#  datetime.datetime(1973, 12, 31, 17, 6, 24),
#  datetime.datetime(1973, 12, 29, 4, 19, 25),
#  datetime.datetime(1973, 12, 22, 13, 13, 39),
#  datetime.datetime(1973, 12, 17, 8, 40, 19),
#  datetime.datetime(1973, 12, 16, 17, 32, 4),
#  datetime.datetime(1973, 12, 8, 23, 36, 36),
#  datetime.datetime(1973, 12, 8, 0, 46, 5),
#  datetime.datetime(1973, 12, 7, 21, 43, 44),
#  datetime.datetime(1973, 12, 4, 7, 19, 57),
#  datetime.datetime(1973, 12, 1, 14, 0, 56),
#  datetime.datetime(1973, 12, 1, 11, 34, 10),
#  datetime.datetime(1973, 11, 30, 2, 26, 9),
#  datetime.datetime(1973, 11, 28, 8, 21),
#  datetime.datetime(1973, 11, 27, 13, 53, 19),
#  datetime.datetime(1973, 11, 25, 8, 11, 19),
#  datetime.datetime(1973, 11, 25, 1, 33, 19),
#  datetime.datetime(1973, 11, 21, 10, 24, 31),
#  datetime.datetime(1973, 11, 21, 0, 23, 9),
#  datetime.datetime(1973, 11, 20, 17, 39, 27),
#  datetime.datetime(1973, 11, 19, 15, 40, 5),
#  datetime.datetime(1973, 11, 17, 16, 28, 39),
#  datetime.datetime(1973, 11, 17, 16, 19, 11),
#  datetime.datetime(1973, 11, 16, 18, 30, 44),
#  datetime.datetime(1973, 11, 13, 21, 57, 31),
#  datetime.datetime(1973, 11, 8, 9, 17, 24),
#  datetime.datetime(1973, 11, 7, 10, 4, 53),
#  datetime.datetime(1973, 11, 5, 6, 52, 33),
#  datetime.datetime(1973, 11, 4, 18, 55, 4),
#  datetime.datetime(1973, 11, 4, 11, 38, 51),
#  datetime.datetime(1973, 11, 3, 11, 17, 41),
#  datetime.datetime(1973, 11, 3, 1, 34, 36),
#  datetime.datetime(1973, 11, 1, 12, 18, 26),
#  datetime.datetime(1973, 11, 1, 7, 38, 5),
#  datetime.datetime(1973, 10, 31, 3, 58, 27),
#  datetime.datetime(1973, 10, 28, 5, 14, 29),
#  datetime.datetime(1973, 10, 27, 16, 16, 1),
#  datetime.datetime(1973, 10, 26, 23, 2, 13),
#  datetime.datetime(1973, 10, 26, 16, 49, 30),
#  datetime.datetime(1973, 10, 26, 8, 15, 42),
#  datetime.datetime(1973, 10, 24, 19, 14, 24),
#  datetime.datetime(1973, 10, 24, 2, 56, 52),
#  datetime.datetime(1973, 10, 22, 3, 15, 23),
#  datetime.datetime(1973, 10, 20, 9, 31, 59),
#  datetime.datetime(1973, 10, 19, 14, 54, 5),
#  datetime.datetime(1973, 10, 19, 7, 11, 16),
#  datetime.datetime(1973, 10, 18, 14, 46, 13),
#  datetime.datetime(1973, 10, 12, 21, 52, 41),
#  datetime.datetime(1973, 10, 12, 1, 9, 3),
#  datetime.datetime(1973, 10, 10, 18, 9, 43),
#  datetime.datetime(1973, 10, 10, 2, 56, 31),
#  datetime.datetime(1973, 10, 9, 19, 38, 49),
#  datetime.datetime(1973, 10, 8, 9, 13, 24),
#  datetime.datetime(1973, 10, 8, 1, 7, 34),
#  datetime.datetime(1973, 10, 6, 19, 45, 40),
#  datetime.datetime(1973, 10, 6, 19, 25, 54),
#  datetime.datetime(1973, 10, 6, 18, 56, 44),
#  datetime.datetime(1973, 10, 6, 12, 55, 2),
#  datetime.datetime(1973, 10, 6, 9, 23, 38),
#  datetime.datetime(1973, 10, 6, 7, 53, 11),
#  datetime.datetime(1973, 10, 6, 3, 48, 6),
#  datetime.datetime(1973, 10, 6, 3, 43, 37),
#  datetime.datetime(1973, 10, 6, 1, 24, 49),
#  datetime.datetime(1973, 10, 5, 22, 42, 54),
#  datetime.datetime(1973, 10, 5, 22, 23, 10),
#  datetime.datetime(1973, 10, 5, 20, 20, 6),
#  datetime.datetime(1973, 10, 5, 17, 56, 39),
#  datetime.datetime(1973, 10, 5, 17, 34, 21),
#  datetime.datetime(1973, 10, 5, 16, 40, 17),
#  datetime.datetime(1973, 10, 5, 13, 48, 54),
#  datetime.datetime(1973, 10, 5, 12, 54, 44),
#  datetime.datetime(1973, 10, 5, 10, 59, 24),
#  datetime.datetime(1973, 10, 5, 9, 58, 2),
#  datetime.datetime(1973, 10, 5, 7, 14, 14),
#  datetime.datetime(1973, 10, 5, 6, 48, 31),
#  datetime.datetime(1973, 10, 5, 6, 44, 8),
#  datetime.datetime(1973, 10, 5, 6, 18, 26),
#  datetime.datetime(1973, 10, 5, 6, 12, 17),
#  datetime.datetime(1973, 10, 5, 5, 57, 21),
#  datetime.datetime(1973, 10, 5, 5, 14, 41),
#  datetime.datetime(1973, 10, 5, 4, 38, 41),
#  datetime.datetime(1973, 10, 5, 4, 23, 16),
#  datetime.datetime(1973, 10, 5, 4, 7, 33),
#  datetime.datetime(1973, 10, 5, 4, 3, 46),
#  datetime.datetime(1973, 10, 5, 3, 56, 19),
#  datetime.datetime(1973, 10, 5, 3, 18, 52),
#  datetime.datetime(1973, 10, 5, 2, 47, 51),
#  datetime.datetime(1973, 10, 5, 2, 45, 27),
#  datetime.datetime(1973, 10, 5, 0, 29, 38),
#  datetime.datetime(1973, 10, 3, 21, 22, 4),
#  datetime.datetime(1973, 10, 3, 20, 33, 39),
#  datetime.datetime(1973, 10, 3, 3, 33, 57),
#  datetime.datetime(1973, 10, 2, 21, 26, 3),
#  datetime.datetime(1973, 10, 2, 14, 39, 52),
#  datetime.datetime(1973, 9, 28, 10, 52, 29),
#  datetime.datetime(1973, 9, 28, 5, 18, 56),
#  datetime.datetime(1973, 9, 23, 17, 38, 7),
#  datetime.datetime(1973, 9, 23, 12, 26, 3),
#  datetime.datetime(1973, 9, 22, 5, 35, 38),
#  datetime.datetime(1973, 9, 21, 17, 11, 59),
#  datetime.datetime(1973, 9, 20, 9, 22, 26),
#  datetime.datetime(1973, 9, 18, 10, 7, 9),
#  datetime.datetime(1973, 9, 18, 6, 39, 13),
#  datetime.datetime(1973, 9, 17, 5, 6, 37),
#  datetime.datetime(1973, 9, 12, 20, 49, 59),
#  datetime.datetime(1973, 9, 9, 4, 45, 43),
#  datetime.datetime(1973, 9, 3, 11, 48, 45),
#  datetime.datetime(1973, 9, 1, 11, 27, 8),
#  datetime.datetime(1973, 8, 29, 20, 17, 52),
#  datetime.datetime(1973, 8, 27, 20, 31, 19),
#  datetime.datetime(1973, 8, 27, 20, 4, 57),
#  datetime.datetime(1973, 8, 27, 8, 1, 21),
#  datetime.datetime(1973, 8, 26, 16, 54, 34),
#  datetime.datetime(1973, 8, 26, 12, 52, 28),
#  datetime.datetime(1973, 8, 25, 21, 23, 28),
#  datetime.datetime(1973, 8, 25, 6, 11, 5),
#  datetime.datetime(1973, 8, 25, 2, 11, 46),
#  datetime.datetime(1973, 8, 25, 0, 11, 35),
#  datetime.datetime(1973, 8, 23, 0, 14, 18),
#  datetime.datetime(1973, 8, 17, 9, 40, 42),
#  datetime.datetime(1973, 8, 16, 2, 31, 11),
#  datetime.datetime(1973, 8, 16, 1, 12, 43),
#  datetime.datetime(1973, 8, 15, 23, 14, 46),
#  datetime.datetime(1973, 8, 13, 23, 17, 32),
#  datetime.datetime(1973, 8, 13, 22, 19, 53),
#  datetime.datetime(1973, 8, 13, 21, 57),
#  datetime.datetime(1973, 8, 10, 12, 5, 21),
#  datetime.datetime(1973, 8, 8, 8, 14, 42),
#  datetime.datetime(1973, 8, 7, 23, 38, 39),
#  datetime.datetime(1973, 8, 7, 10, 22, 45),
#  datetime.datetime(1973, 8, 7, 10, 1, 1),
#  datetime.datetime(1973, 8, 7, 7, 15, 11),
#  datetime.datetime(1973, 8, 7, 6, 23, 40),
#  datetime.datetime(1973, 8, 7, 6, 4, 26),
#  datetime.datetime(1973, 8, 7, 3, 13, 32),
#  datetime.datetime(1973, 8, 7, 0, 59, 3),
#  datetime.datetime(1973, 8, 6, 23, 41, 25),
#  datetime.datetime(1973, 8, 6, 9, 6, 27),
#  datetime.datetime(1973, 8, 6, 3, 29, 11),
#  datetime.datetime(1973, 8, 4, 20, 49, 58),
#  datetime.datetime(1973, 8, 4, 20, 19, 40),
#  datetime.datetime(1973, 8, 4, 18, 44, 44),
#  datetime.datetime(1973, 8, 4, 7, 22, 28),
#  datetime.datetime(1973, 8, 2, 18, 11, 25),
#  datetime.datetime(1973, 8, 2, 8, 55, 36),
#  datetime.datetime(1973, 8, 1, 14, 9, 12),
#  datetime.datetime(1973, 8, 1, 13, 38, 41),
#  datetime.datetime(1973, 8, 1, 11, 44, 25),
#  datetime.datetime(1973, 8, 1, 8, 30, 2),
#  datetime.datetime(1973, 8, 1, 7, 13, 37),
#  datetime.datetime(1973, 8, 1, 7, 8, 28),
#  datetime.datetime(1973, 7, 31, 17, 51, 18),
#  datetime.datetime(1973, 7, 31, 11, 17, 49),
#  datetime.datetime(1973, 7, 31, 9, 34, 7),
#  datetime.datetime(1973, 7, 31, 8, 57, 18),
#  datetime.datetime(1973, 7, 31, 8, 47, 26),
#  datetime.datetime(1973, 7, 31, 8, 32, 28),
#  datetime.datetime(1973, 7, 31, 8, 24, 25),
#  datetime.datetime(1973, 7, 31, 6, 51, 13),
#  datetime.datetime(1973, 7, 31, 5, 59, 43),
#  datetime.datetime(1973, 7, 31, 1, 41, 4),
#  datetime.datetime(1973, 7, 28, 1, 59, 46),
#  datetime.datetime(1973, 7, 27, 14, 33, 42),
#  datetime.datetime(1973, 7, 27, 1, 27, 41),
#  datetime.datetime(1973, 7, 26, 19, 17, 47),
#  datetime.datetime(1973, 7, 26, 5, 19, 58),
#  datetime.datetime(1973, 7, 26, 2, 36, 10),
#  datetime.datetime(1973, 7, 24, 16, 3, 35),
#  datetime.datetime(1973, 7, 23, 7, 16, 50),
#  datetime.datetime(1973, 7, 21, 12, 20, 46),
#  datetime.datetime(1973, 7, 21, 11, 39, 5),
#  datetime.datetime(1973, 7, 18, 11, 21, 23),
#  datetime.datetime(1973, 7, 18, 1, 19, 24),
#  datetime.datetime(1973, 7, 17, 21, 16, 54),
#  datetime.datetime(1973, 7, 14, 2, 32, 50),
#  datetime.datetime(1973, 7, 13, 19, 19, 8),
#  datetime.datetime(1973, 7, 12, 20, 22, 16),
#  datetime.datetime(1973, 7, 12, 19, 26, 12),
#  datetime.datetime(1973, 7, 12, 12, 25, 11),
#  datetime.datetime(1973, 7, 12, 11, 48, 38),
#  datetime.datetime(1973, 7, 12, 11, 41, 39),
#  datetime.datetime(1973, 7, 12, 11, 11, 11),
#  datetime.datetime(1973, 7, 12, 9, 45, 30),
#  datetime.datetime(1973, 7, 11, 16, 10, 2),
#  datetime.datetime(1973, 7, 11, 12, 44, 26),
#  datetime.datetime(1973, 7, 11, 8, 28, 53),
#  datetime.datetime(1973, 7, 10, 19, 26, 43),
#  datetime.datetime(1973, 7, 10, 13, 2, 35),
#  datetime.datetime(1973, 7, 10, 11, 6),
#  datetime.datetime(1973, 7, 9, 19, 50, 50),
#  datetime.datetime(1973, 7, 9, 18, 20, 21),
#  datetime.datetime(1973, 7, 9, 16, 18, 18),
#  datetime.datetime(1973, 7, 9, 9, 16, 45),
#  datetime.datetime(1973, 7, 8, 20, 57, 31),
#  datetime.datetime(1973, 7, 8, 18, 49, 15),
#  datetime.datetime(1973, 7, 8, 16, 47, 40),
#  datetime.datetime(1973, 7, 8, 14, 12, 7),
#  datetime.datetime(1973, 7, 8, 1, 13, 32),
#  datetime.datetime(1973, 7, 7, 23, 2, 30),
#  datetime.datetime(1973, 7, 7, 22, 26, 14),
#  datetime.datetime(1973, 7, 7, 22, 0, 1),
#  datetime.datetime(1973, 7, 7, 21, 13, 6),
#  datetime.datetime(1973, 7, 7, 21, 8, 5),
#  datetime.datetime(1973, 7, 7, 20, 54, 41),
#  datetime.datetime(1973, 7, 7, 20, 49, 51),
#  datetime.datetime(1973, 7, 7, 15, 26, 52),
#  datetime.datetime(1973, 7, 7, 14, 44, 32),
#  datetime.datetime(1973, 7, 7, 14, 38, 45),
#  datetime.datetime(1973, 7, 7, 8, 45),
#  datetime.datetime(1973, 7, 7, 1, 2, 40),
#  datetime.datetime(1973, 7, 6, 16, 30, 7),
#  datetime.datetime(1973, 7, 6, 12, 56, 42),
#  datetime.datetime(1973, 7, 6, 8, 52, 26),
#  datetime.datetime(1973, 7, 6, 7, 59, 30),
#  datetime.datetime(1973, 7, 6, 6, 58, 40),
#  datetime.datetime(1973, 7, 6, 5, 27, 30),
#  datetime.datetime(1973, 7, 6, 3, 23, 31),
#  datetime.datetime(1973, 7, 6, 1, 26, 8),
#  datetime.datetime(1973, 7, 5, 20, 13, 35),
#  datetime.datetime(1973, 7, 5, 9, 37, 11),
#  datetime.datetime(1973, 7, 5, 5, 25, 52),
#  datetime.datetime(1973, 7, 5, 1, 32, 52),
#  datetime.datetime(1973, 7, 5, 1, 13, 18),
#  datetime.datetime(1973, 7, 5, 0, 50, 33),
#  datetime.datetime(1973, 7, 5, 0, 24, 11),
#  datetime.datetime(1973, 7, 3, 21, 49, 6),
#  datetime.datetime(1973, 7, 3, 20, 26, 30),
#  datetime.datetime(1973, 7, 3, 17, 41, 52),
#  datetime.datetime(1973, 7, 2, 5, 50, 28),
#  datetime.datetime(1973, 6, 28, 12, 42, 6),
#  datetime.datetime(1973, 6, 28, 11, 26, 40),
#  datetime.datetime(1973, 6, 24, 12, 8, 46),
#  datetime.datetime(1973, 6, 23, 13, 24, 34),
#  datetime.datetime(1973, 6, 21, 16, 36, 33),
#  datetime.datetime(1973, 6, 21, 9, 39, 29),
#  datetime.datetime(1973, 6, 19, 3, 16, 55),
#  datetime.datetime(1973, 6, 19, 0, 46, 1),
#  datetime.datetime(1973, 6, 17, 14, 9, 51),
#  datetime.datetime(1973, 6, 11, 2, 7, 40),
#  datetime.datetime(1973, 6, 9, 1, 12, 48),
#  datetime.datetime(1973, 6, 6, 3, 42, 20),
#  datetime.datetime(1973, 6, 3, 4, 52, 5),
#  datetime.datetime(1973, 5, 31, 5, 5, 38),
#  datetime.datetime(1973, 5, 30, 16, 46, 8),
#  datetime.datetime(1973, 5, 30, 13, 0, 45),
#  datetime.datetime(1973, 5, 29, 9, 25, 17),
#  datetime.datetime(1973, 5, 27, 21, 53, 52),
#  datetime.datetime(1973, 5, 25, 22, 5, 30),
#  datetime.datetime(1973, 5, 25, 5, 45, 12),
#  datetime.datetime(1973, 5, 24, 4, 33, 6),
#  datetime.datetime(1973, 5, 22, 13, 40, 52),
#  datetime.datetime(1973, 5, 21, 23, 2, 18),
#  datetime.datetime(1973, 5, 15, 3, 34, 46),
#  datetime.datetime(1973, 5, 13, 13, 34, 49),
#  datetime.datetime(1973, 5, 10, 3, 55, 7),
#  datetime.datetime(1973, 5, 9, 10, 40, 32),
#  datetime.datetime(1973, 5, 9, 0, 6, 40),
#  datetime.datetime(1973, 5, 8, 17, 40, 55),
#  datetime.datetime(1973, 5, 8, 16, 28, 30),
#  datetime.datetime(1973, 5, 8, 15, 34, 31),
#  datetime.datetime(1973, 5, 8, 11, 54, 47),
#  datetime.datetime(1973, 5, 8, 2, 58, 49),
#  datetime.datetime(1973, 5, 7, 6, 48, 30),
#  datetime.datetime(1973, 5, 7, 6, 22, 49),
#  datetime.datetime(1973, 5, 6, 17, 12, 43),
#  datetime.datetime(1973, 5, 5, 11, 47, 4),
#  datetime.datetime(1973, 5, 3, 13, 39, 29),
#  datetime.datetime(1973, 5, 3, 12, 0, 32),
#  datetime.datetime(1973, 5, 2, 9, 39, 45),
#  datetime.datetime(1973, 5, 1, 22, 13, 27),
#  datetime.datetime(1973, 4, 29, 17, 53, 45),
#  datetime.datetime(1973, 4, 28, 9, 3, 3),
#  datetime.datetime(1973, 4, 28, 3, 14, 26),
#  datetime.datetime(1973, 4, 26, 2, 54, 40),
#  datetime.datetime(1973, 4, 23, 11, 25),
#  datetime.datetime(1973, 4, 22, 10, 54, 49),
#  datetime.datetime(1973, 4, 22, 7, 12, 12),
#  datetime.datetime(1973, 4, 18, 16, 11, 18),
#  datetime.datetime(1973, 4, 13, 18, 36, 39),
#  datetime.datetime(1973, 4, 9, 7, 53, 53),
#  datetime.datetime(1973, 4, 8, 22, 13, 1),
#  datetime.datetime(1973, 4, 7, 18, 50, 54),
#  datetime.datetime(1973, 4, 7, 18, 12, 19),
#  datetime.datetime(1973, 4, 7, 3, 16, 22),
#  datetime.datetime(1973, 4, 5, 20, 24, 4),
#  datetime.datetime(1973, 4, 5, 2, 15, 45),
#  datetime.datetime(1973, 4, 5, 1, 28, 4),
#  datetime.datetime(1973, 4, 4, 4, 45, 12),
#  datetime.datetime(1973, 4, 4, 4, 18, 27),
#  datetime.datetime(1973, 4, 4, 0, 14, 17),
#  datetime.datetime(1973, 4, 3, 18, 7, 36),
#  datetime.datetime(1973, 4, 3, 11, 39, 12),
#  datetime.datetime(1973, 3, 26, 8, 11, 18),
#  datetime.datetime(1973, 3, 26, 7, 4, 19),
#  datetime.datetime(1973, 3, 24, 8, 10, 45),
#  datetime.datetime(1973, 3, 23, 21, 14, 25),
#  datetime.datetime(1973, 3, 22, 20, 37, 1),
#  datetime.datetime(1973, 3, 20, 12, 17, 30),
#  datetime.datetime(1973, 3, 20, 1, 12, 44),
#  datetime.datetime(1973, 3, 18, 0, 39, 47),
#  datetime.datetime(1973, 3, 17, 8, 44, 32),
#  datetime.datetime(1973, 3, 13, 13, 46, 46),
#  datetime.datetime(1973, 3, 12, 2, 56, 19),
#  datetime.datetime(1973, 3, 11, 5, 29, 58),
#  datetime.datetime(1973, 3, 7, 13, 38, 16),
#  datetime.datetime(1973, 3, 5, 19, 48, 59),
#  datetime.datetime(1973, 3, 4, 18, 9, 21),
#  datetime.datetime(1973, 3, 3, 20, 37, 2),
#  datetime.datetime(1973, 3, 2, 15, 30, 56),
#  datetime.datetime(1973, 2, 27, 1, 36, 49),
#  datetime.datetime(1973, 2, 26, 15, 52, 45),
#  datetime.datetime(1973, 2, 25, 19, 33, 29),
#  datetime.datetime(1973, 2, 24, 7, 34, 6),
#  datetime.datetime(1973, 2, 23, 2, 5, 40),
#  datetime.datetime(1973, 2, 18, 15, 33, 24),
#  datetime.datetime(1973, 2, 15, 23, 34, 7),
#  datetime.datetime(1973, 2, 15, 8, 8),
#  datetime.datetime(1973, 2, 13, 3, 23, 42),
#  datetime.datetime(1973, 2, 12, 23, 4, 53),
#  datetime.datetime(1973, 2, 11, 23, 31, 5),
#  datetime.datetime(1973, 2, 9, 23, 51, 55),
#  datetime.datetime(1973, 2, 9, 4, 41, 22),
#  datetime.datetime(1973, 2, 8, 6, 38, 43),
#  datetime.datetime(1973, 2, 8, 1, 19, 25),
#  datetime.datetime(1973, 2, 7, 13, 55, 52),
#  datetime.datetime(1973, 2, 7, 4, 14, 58),
#  datetime.datetime(1973, 2, 6, 3, 27, 31),
#  datetime.datetime(1973, 2, 5, 23, 50, 54),
#  datetime.datetime(1973, 2, 2, 1, 51, 19),
#  datetime.datetime(1973, 2, 1, 2, 14, 20),
#  datetime.datetime(1973, 1, 30, 12, 3, 23),
#  datetime.datetime(1973, 1, 29, 17, 0, 13),
#  datetime.datetime(1973, 1, 29, 4, 39, 43),
#  datetime.datetime(1973, 1, 24, 6, 3, 36),
#  datetime.datetime(1973, 1, 22, 6, 50, 53),
#  datetime.datetime(1973, 1, 21, 23, 21, 5),
#  datetime.datetime(1973, 1, 19, 7, 33, 50),
#  datetime.datetime(1973, 1, 18, 2, 17),
#  datetime.datetime(1973, 1, 17, 16, 25, 49),
#  datetime.datetime(1973, 1, 17, 2, 57, 16),
#  datetime.datetime(1973, 1, 10, 2, 1, 28),
#  datetime.datetime(1973, 1, 8, 17, 43, 23),
#  datetime.datetime(1973, 1, 6, 3, 18, 52),
#  datetime.datetime(1972, 12, 29, 1, 51, 1),
#  datetime.datetime(1972, 11, 7, 2, 35, 22),
#  datetime.datetime(1972, 11, 3, 20, 57, 56),
#  datetime.datetime(1972, 10, 10, 18, 42, 19),
#  datetime.datetime(1972, 10, 2, 16, 35, 47),
#  datetime.datetime(1972, 9, 26, 17, 5, 45),
#  datetime.datetime(1972, 8, 13, 7, 47, 46),
#  datetime.datetime(1972, 6, 8, 14, 53, 44),
#  datetime.datetime(1972, 6, 8, 13, 57, 39),
#  datetime.datetime(1972, 5, 15, 6, 9, 37),
#  datetime.datetime(1972, 5, 13, 11, 19, 38),
#  datetime.datetime(1972, 3, 30, 7, 0, 18),
#  datetime.datetime(1972, 3, 1, 18, 39, 44),
#  datetime.datetime(1972, 2, 15, 18, 18, 20),
#  datetime.datetime(1972, 2, 9, 17, 44, 35),
#  datetime.datetime(1972, 2, 4, 10, 29, 15),
#  datetime.datetime(1971, 12, 8, 13, 5, 28),
#  datetime.datetime(1971, 11, 28, 8, 12, 2),
#  datetime.datetime(1971, 10, 13, 19, 36, 5),
#  datetime.datetime(1971, 9, 28, 19, 16, 2),
#  datetime.datetime(1971, 9, 25, 9, 5, 57),
#  datetime.datetime(1971, 8, 21, 8, 47, 49),
#  datetime.datetime(1971, 8, 14, 11, 0, 25),
#  datetime.datetime(1971, 7, 31, 18, 8, 48),
#  datetime.datetime(1971, 7, 17, 16, 10, 22),
#  datetime.datetime(1971, 7, 11, 5, 51, 39),
#  datetime.datetime(1971, 7, 8, 23, 3, 20),
#  datetime.datetime(1971, 7, 3, 19, 44, 51),
#  datetime.datetime(1971, 6, 29, 2, 1, 24),
#  datetime.datetime(1971, 6, 17, 17, 0, 43),
#  datetime.datetime(1971, 5, 18, 2, 12, 36),
#  datetime.datetime(1971, 5, 7, 20, 49, 46),
#  datetime.datetime(1971, 4, 20, 10, 12, 47),
#  datetime.datetime(1971, 4, 7, 11, 10, 39),
#  datetime.datetime(1971, 2, 21, 7, 35, 22),
#  datetime.datetime(1971, 2, 18, 4, 47, 30),
#  datetime.datetime(1970, 12, 8, 16, 30, 8),
#  datetime.datetime(1970, 12, 4, 14, 8, 50),
#  datetime.datetime(1970, 11, 28, 11, 45, 34),
#  datetime.datetime(1970, 11, 28, 8, 8, 45),
#  datetime.datetime(1970, 11, 12, 21, 9, 1),
#  datetime.datetime(1970, 9, 19, 2, 37, 29),
#  datetime.datetime(1970, 9, 14, 11, 36, 50),
#  datetime.datetime(1970, 6, 19, 6, 56, 16),
#  datetime.datetime(1970, 6, 13, 20, 0, 11),
#  datetime.datetime(1970, 6, 11, 2, 2, 56),
#  datetime.datetime(1970, 3, 15, 9, 39, 18),
#  datetime.datetime(1979, 12, 30, 9, 36, 47),
#  datetime.datetime(1979, 12, 30, 3, 25, 48),
#  datetime.datetime(1979, 12, 29, 15, 16, 39),
#  datetime.datetime(1979, 12, 28, 10, 46, 18),
#  datetime.datetime(1979, 12, 26, 16, 43, 37),
#  datetime.datetime(1979, 12, 26, 1, 24, 38),
#  datetime.datetime(1979, 12, 25, 9, 59, 1),
#  datetime.datetime(1979, 12, 23, 21, 13, 41),
#  datetime.datetime(1979, 12, 13, 1, 36, 27),
#  datetime.datetime(1979, 12, 13, 0, 38, 26),
#  datetime.datetime(1979, 12, 11, 2, 24, 54),
#  datetime.datetime(1979, 12, 10, 8, 4),
#  datetime.datetime(1979, 12, 8, 4, 7, 13),
#  datetime.datetime(1979, 12, 7, 12, 31, 47),
#  datetime.datetime(1979, 12, 3, 16, 52, 15),
#  datetime.datetime(1979, 12, 3, 12, 52, 12),
#  datetime.datetime(1979, 12, 3, 8, 43, 24),
#  datetime.datetime(1979, 11, 30, 22, 30, 17),
#  datetime.datetime(1979, 11, 30, 9, 56, 53),
#  datetime.datetime(1979, 11, 29, 10, 33, 15),
#  datetime.datetime(1979, 11, 29, 0, 16, 15),
#  datetime.datetime(1979, 11, 28, 13, 19, 23),
#  datetime.datetime(1979, 11, 28, 10, 46, 19),
#  datetime.datetime(1979, 11, 28, 4, 10, 48),
#  datetime.datetime(1979, 11, 28, 1, 9, 21),
#  datetime.datetime(1979, 11, 27, 14, 37, 25),
#  datetime.datetime(1979, 11, 27, 5, 4, 47),
#  datetime.datetime(1979, 11, 26, 10, 1, 40),
#  datetime.datetime(1979, 11, 26, 8, 24, 2),
#  datetime.datetime(1979, 11, 24, 16, 33, 33),
#  datetime.datetime(1979, 11, 24, 15, 13, 42),
#  datetime.datetime(1979, 11, 24, 12, 29, 38),
#  datetime.datetime(1979, 11, 24, 1, 58, 54),
#  datetime.datetime(1979, 11, 24, 0, 41, 15),
#  datetime.datetime(1979, 11, 23, 16, 29, 32),
#  datetime.datetime(1979, 11, 22, 14, 3, 10),
#  datetime.datetime(1979, 11, 22, 11, 48, 26),
#  datetime.datetime(1979, 11, 22, 9, 13, 45),
#  datetime.datetime(1979, 11, 21, 23, 41, 16),
#  datetime.datetime(1979, 11, 21, 3, 51, 16),
#  datetime.datetime(1979, 11, 19, 1, 38, 12),
#  datetime.datetime(1979, 11, 14, 2, 38, 48),
#  datetime.datetime(1979, 11, 11, 17, 37, 20),
#  datetime.datetime(1979, 11, 10, 15, 32, 24),
#  datetime.datetime(1979, 11, 7, 21, 20, 15),
#  datetime.datetime(1979, 11, 6, 12, 49, 9),
#  datetime.datetime(1979, 11, 5, 15, 43, 6),
#  datetime.datetime(1979, 11, 4, 17, 45, 57),
#  datetime.datetime(1979, 11, 3, 9, 34, 20),
#  datetime.datetime(1979, 10, 31, 5, 59),
#  datetime.datetime(1979, 10, 27, 21, 3, 11),
#  datetime.datetime(1979, 10, 27, 7, 37, 32),
#  datetime.datetime(1979, 10, 27, 3, 28, 2),
#  datetime.datetime(1979, 10, 27, 0, 55, 40),
#  datetime.datetime(1979, 10, 25, 14, 52, 57),
#  datetime.datetime(1979, 10, 25, 1, 43),
#  datetime.datetime(1979, 10, 24, 6, 57, 58),
#  datetime.datetime(1979, 10, 23, 23, 5, 39),
#  datetime.datetime(1979, 10, 23, 18, 3, 47),
#  datetime.datetime(1979, 10, 22, 2, 15, 7),
#  datetime.datetime(1979, 10, 22, 0, 26, 26),
#  datetime.datetime(1979, 10, 20, 16, 19, 25),
#  datetime.datetime(1979, 10, 20, 14, 17, 49),
#  datetime.datetime(1979, 10, 19, 0, 50, 8),
#  datetime.datetime(1979, 10, 17, 16, 37, 59),
#  datetime.datetime(1979, 10, 15, 20, 48, 15),
#  datetime.datetime(1979, 10, 14, 7, 39, 49),
#  datetime.datetime(1979, 10, 13, 22, 13, 42),
#  datetime.datetime(1979, 10, 12, 4, 5, 44),
#  datetime.datetime(1979, 10, 11, 18, 41, 57),
#  datetime.datetime(1979, 10, 11, 18, 35, 48),
#  datetime.datetime(1979, 10, 11, 15, 2, 44),
#  datetime.datetime(1979, 10, 11, 12, 20, 4),
#  datetime.datetime(1979, 10, 11, 4, 55, 56),
#  datetime.datetime(1979, 10, 10, 17, 40, 52),
#  datetime.datetime(1979, 10, 9, 15, 34, 29),
#  datetime.datetime(1979, 10, 8, 5, 26, 3),
#  datetime.datetime(1979, 10, 8, 3, 59, 53),
#  datetime.datetime(1979, 10, 7, 22, 25, 1),
#  datetime.datetime(1979, 10, 7, 21, 52, 36),
#  datetime.datetime(1979, 10, 7, 18, 55, 4),
#  datetime.datetime(1979, 10, 4, 7, 18, 30),
#  datetime.datetime(1979, 10, 3, 2, 2, 28),
#  datetime.datetime(1979, 10, 2, 1, 43, 23),
#  datetime.datetime(1979, 9, 30, 7, 13, 32),
#  datetime.datetime(1979, 9, 30, 4, 15, 5),
#  datetime.datetime(1979, 9, 29, 17, 4, 41),
#  datetime.datetime(1979, 9, 29, 16, 52, 26),
#  datetime.datetime(1979, 9, 29, 11, 16, 30),
#  datetime.datetime(1979, 9, 29, 6, 6, 34),
#  datetime.datetime(1979, 9, 29, 0, 28, 42),
#  datetime.datetime(1979, 9, 28, 23, 32, 51),
#  datetime.datetime(1979, 9, 24, 10, 50, 55),
#  datetime.datetime(1979, 9, 24, 6, 3, 35),
#  datetime.datetime(1979, 9, 22, 21, 3, 55),
#  datetime.datetime(1979, 9, 21, 22, 43, 35),
#  datetime.datetime(1979, 9, 21, 21, 41, 52),
#  datetime.datetime(1979, 9, 21, 18, 46, 33),
#  datetime.datetime(1979, 9, 20, 5, 7, 30),
#  datetime.datetime(1979, 9, 19, 19, 8, 1),
#  datetime.datetime(1979, 9, 19, 9, 37, 58),
#  datetime.datetime(1979, 9, 19, 3, 37, 26),
#  datetime.datetime(1979, 9, 18, 12, 11, 51),
#  datetime.datetime(1979, 9, 18, 3, 42, 59),
#  datetime.datetime(1979, 9, 16, 22, 2, 44),
#  datetime.datetime(1979, 9, 16, 12, 21, 7),
#  datetime.datetime(1979, 9, 15, 6, 41, 26),
#  datetime.datetime(1979, 9, 9, 23, 32, 45),
#  datetime.datetime(1979, 9, 8, 10, 48, 53),
#  datetime.datetime(1979, 9, 6, 8, 35, 8),
#  datetime.datetime(1979, 9, 5, 16, 47, 51),
#  datetime.datetime(1979, 9, 4, 0, 58, 22),
#  datetime.datetime(1979, 9, 2, 10, 29, 40),
#  datetime.datetime(1979, 8, 31, 2, 47, 36),
#  datetime.datetime(1979, 8, 30, 17, 17, 45),
#  datetime.datetime(1979, 8, 30, 14, 59, 45),
#  datetime.datetime(1979, 8, 30, 6, 49, 12),
#  datetime.datetime(1979, 8, 30, 5, 15, 49),
#  datetime.datetime(1979, 8, 28, 13, 12, 49),
#  datetime.datetime(1979, 8, 28, 12, 23, 53),
#  datetime.datetime(1979, 8, 28, 10, 20, 29),
#  datetime.datetime(1979, 8, 25, 7, 27, 6),
#  datetime.datetime(1979, 8, 24, 20, 8, 59),
#  datetime.datetime(1979, 8, 23, 21, 47, 46),
#  datetime.datetime(1979, 8, 23, 21, 35, 38),
#  datetime.datetime(1979, 8, 23, 8, 36, 54),
#  datetime.datetime(1979, 8, 23, 5, 37, 42),
#  datetime.datetime(1979, 8, 22, 5, 38, 33),
#  datetime.datetime(1979, 8, 22, 4, 26, 9),
#  datetime.datetime(1979, 8, 21, 15, 44, 9),
#  datetime.datetime(1979, 8, 21, 3, 57, 21),
#  datetime.datetime(1979, 8, 21, 3, 17, 57),
#  datetime.datetime(1979, 8, 20, 7, 26, 59),
#  datetime.datetime(1979, 8, 20, 2, 4, 7),
#  datetime.datetime(1979, 8, 20, 2, 2, 5),
#  datetime.datetime(1979, 8, 18, 2, 26, 33),
#  datetime.datetime(1979, 8, 16, 2, 47, 39),
#  datetime.datetime(1979, 8, 16, 1, 24, 55),
#  datetime.datetime(1979, 8, 15, 0, 27, 42),
#  datetime.datetime(1979, 8, 14, 12, 13, 22),
#  datetime.datetime(1979, 8, 13, 19, 8, 10),
#  datetime.datetime(1979, 8, 13, 11, 31, 27),
#  datetime.datetime(1979, 8, 13, 10, 48, 50),
#  datetime.datetime(1979, 8, 11, 9, 40, 11),
#  datetime.datetime(1979, 8, 9, 23, 57, 5),
#  datetime.datetime(1979, 8, 9, 21, 28, 42),
#  datetime.datetime(1979, 8, 9, 10, 5, 47),
#  datetime.datetime(1979, 8, 8, 15, 40, 59),
#  datetime.datetime(1979, 8, 8, 5, 17, 42),
#  datetime.datetime(1979, 8, 7, 16, 27),
#  datetime.datetime(1979, 8, 6, 13, 40, 35),
#  datetime.datetime(1979, 8, 2, 10, 58, 53),
#  datetime.datetime(1979, 8, 2, 5, 4, 50),
#  datetime.datetime(1979, 8, 2, 3, 40, 23),
#  datetime.datetime(1979, 7, 31, 21, 58, 42),
#  datetime.datetime(1979, 7, 31, 15, 20, 5),
#  datetime.datetime(1979, 7, 28, 7, 49, 33),
#  datetime.datetime(1979, 7, 27, 3, 1, 7),
#  datetime.datetime(1979, 7, 27, 1, 12, 53),
#  datetime.datetime(1979, 7, 26, 3, 44, 34),
#  datetime.datetime(1979, 7, 25, 18, 41, 37),
#  datetime.datetime(1979, 7, 25, 13, 45, 9),
#  datetime.datetime(1979, 7, 24, 23, 35, 16),
#  datetime.datetime(1979, 7, 24, 20, 57, 15),
#  datetime.datetime(1979, 7, 24, 13, 16, 10),
#  datetime.datetime(1979, 7, 21, 22, 29, 9),
#  datetime.datetime(1979, 7, 21, 7, 30, 22),
#  datetime.datetime(1979, 7, 20, 22, 38, 2),
#  datetime.datetime(1979, 7, 19, 9, 44, 10),
#  datetime.datetime(1979, 7, 18, 8, 23, 54),
#  datetime.datetime(1979, 7, 16, 14, 13, 47),
#  datetime.datetime(1979, 7, 16, 7, 6, 11),
#  datetime.datetime(1979, 7, 15, 1, 41, 6),
#  datetime.datetime(1979, 7, 14, 9, 53, 40),
#  datetime.datetime(1979, 7, 14, 4, 59, 41),
#  datetime.datetime(1979, 7, 14, 2, 30, 29),
#  datetime.datetime(1979, 7, 12, 3, 8, 35),
#  ...]

# %% [markdown]
# ### Pregunta 6
#
# Transforme las listas de los atributos de interés contenidas en `observaciones_dict` en un `numpy.ndarray` de `dtype` específico.  Para ello, utilice `dtype_dict`, a modo de ejemplo, para los datos contenidos en `observaciones_dict['magnitud']` se debe transformar según  `dtype_dict['magnitud']` en un `numpy.ndarray` de `dtype` `np.dtype(float)`.
# 1. Utilice comprensión de diccionarios y el método `.items()` para transformar los datos. Guarde el resultado en la variable `observaciones_np_dict`.
# 2. Compruebe que el evento más antiguo contenido en `observaciones_np_dict` corresponde al 3 de agosto de 1920.

# %%
# Respuesta P6 1

observaciones_np_dict = { k: np.array(value,dtype=dtype_dict[k])  for k,value in observaciones_dict.items() }
timestamps=observaciones_np_dict['timestamp']
min(timestamps)
# Out:
# numpy.datetime64('1920-08-03T15:14:35.000000000')

# %% [markdown]
# ### Pregunta 7 (opcional)

# %% [markdown]
# El objetivo del ejercicio es obtener estadísticas descriptivas de los movimientos telúricos ocurridos en Chile en los últimos 100 años. Para mostrar dichas estadísticas definiremos la función `muestra_estadisticas_descriptivas` que toma como argumento un  `numpy.ndarray` y muestra en pantalla las siguientes estadísticas según la clase de los elementos contenidos en dicho arreglo:
# - `'np.float64'` y `numpy.datetime64` (`datetime` en nanosegundos): número de observaciones, promedio, mediana, primer cuartil, tercer cuartil, minimo y maximo.
# - `'<U64'` (`str` de largo máximo 64): número de observaciones y moda.
#
# Como el comportamiento debe variar según el tipo de dato del argumento, sería conveniente usar el decorador `singledispatch`. Sin embargo al verificar:
# ```python
# >>>[val.__class__ for val in observaciones_np_dict.values()]
# [numpy.ndarray,
#  numpy.ndarray,
#  numpy.ndarray,
#  numpy.ndarray,
#  numpy.ndarray,
#  numpy.ndarray]
# ```
# observamos que el todos los arrays contenidos en `observaciones_np_dict` pertenecen a la misma clase, `numpy.ndarray`. Por lo tanto es necesario volver a modificar el comportamiento de `singledispatch` para que sea capaz de distinguir entre el `dtype` del array que recibe como argumento.

# %% [markdown]
# 1. Complete el código de la siguiente función para extender la funcionalidad de `singledispatch` para distinguir `dtype` del `numpy.ndarray` usado como argumento.
#
# *Hint* : Revise el código de `singledispatchmeth`, [esta página](https://stackoverflow.com/questions/24601722/how-can-i-use-functools-singledispatch-with-instance-methods) puede ser de ayuda.

# %%
# Respuesta P7 1
def numpydispatch(func):
    despachador = singledispatch(func)

    def wrapper(*args, **kw):
        return despachador.dispatch(_ _ _ _ )(_ _ _ _) # Completar
    
    wrapper.register = despachador.register
    update_wrapper(wrapper, func)
    return wrapper
# Out:
#   File "<ipython-input-21-45869bd723e3>", line 6
#     return despachador.dispatch(_ _ _ _ )(_ _ _ _) # Completar
#                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# 2. Para concluir complete las funciones de `muestra_estadisticas_descriptivas` asociadas a arreglos que contienen elementos de clase `np.float64` y `np.str_`. Estas deben mostrar en pantalla:
#     - `'np.float64'`: número de observaciones, promedio, mediana, primer cuartil, tercer cuartil, minimo y maximo.
#     - `'<U64'` (`str` de largo máximo 64): número de observaciones y moda.
#
#    *Hint*: tenga especial cuidado con los valores faltantes `np.nan` que pueden presentarse en los arreglos con elementos de clase `'np.float64'`. Puede ser útil usar las funciones de `numpy` que permiten el manejo de valores faltantes. Por ejemplo `np.nanmean` como análoga a `np.mean`.
#
#    **Obs**: se provee la función asociada a los array con elementos de la clase `np.datetime64` pues el método `view` está fuera del alcance del ejercicio.
#
#    **Obs**: la notación `f"texto{var}"` es equivalente a `"texto {}".format(var)`. El cuál es un método diseñado para insertar valores dinámicos (variables del entorno) sobre un string.

# %%
# Respuesta P7 2
@numpydispatch
def muestra_estadisticas_descriptivas(array):
    '''Define el comportamiento para objetos en general fuera de registry'''
    print(f"numero de observaciones: {len(array):,}")
        
@muestra_estadisticas_descriptivas.register(np.datetime64)
def _(array):
    '''Define el comportamiento para los objetos '''
    
    # transforma array para que puedan calcularse las estadisticas deseadas
    trans_array = observaciones_arr_dict['timestamp'].view('i8')
    
    # inicializa el contenedor de los str a mostrar en pantalla
    lista_str = []
    
    # genera los str a mostrar en pantalla
    lista_str.append(f"numero de observaciones: {len(array):,}")
    lista_str.append(
        f"media: {trans_array.mean().astype('datetime64[ns]')}"
    )
    lista_str.append(
        f"mediana: {np.median(trans_array).astype('datetime64[ns]')}"
    )
    lista_str.append(
        f"primer cuartil: {np.quantile(trans_array, .25).astype('datetime64[ns]')}"
    )
    lista_str.append(
        f"tercer cuartil: {np.quantile(trans_array, .75).astype('datetime64[ns]')}"
    )
    lista_str.append(
        f"minimo: {trans_array.min().astype('datetime64[ns]')}"
    )
    lista_str.append(
        f"maximo: {trans_array.max().astype('datetime64[ns]')}"
    )
    
    # muestra los elementos de la lista separados por un salto de linea
    print('\n'.join(lista_str))
    
@muestra_estadisticas_descriptivas.register(np.float64)
def _(array):
    # Completar
    
    
@muestra_estadisticas_descriptivas.register(np.str_)
def _(array):
    # Completar
